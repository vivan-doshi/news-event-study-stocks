# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

read_df = pd.read_parquet('/content/drive/MyDrive/DSO585/aggregated_results_topics_sentiment_yf.parquet')

print(read_df.info())

read_df.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4604 entries, 0 to 4603
# Data columns (total 59 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   symbol_query                                          4604 non-null   object
#  1   final_date_for_news                                   4604 non-null   datetime64[ns]
#  2   sentiment_finbert_CEO & Influencer News               4604 non-null   float64
#  3   sentiment_finbert_Corporate Earnings & Financials     4604 non-null   float64
#  4   sentiment_finbert_Corporate Strategy & Growth         4604 non-null   float64
#  5   sentiment_finbert_Economic Indicators & Fed Policy    4604 non-null   float64
#  6   sentiment_finbert_General Business & News Reporting   4604 non-null   float64
#  7   sentiment_finbert_Geopolitical & Trade News           4604 non-null   float64
#  8   sentiment_finbert_Innovation & Future Tech            4604 non-null   float64
#  9   sentiment_finbert_Investment & Hedge Fund Activity    4604 non-null   float64
#  10  sentiment_finbert_Investment Analysis & Strategy      4604 non-null   float64
#  11  sentiment_finbert_Layoffs & Corporate Restructuring   4604 non-null   float64
#  12  sentiment_finbert_Legal & Regulatory Changes          4604 non-null   float64
#  13  sentiment_finbert_Market Movements & Trading News     4604 non-null   float64
#  14  sentiment_finbert_Mergers, Acquisitions & Deals       4604 non-null   float64
#  15  sentiment_finbert_Product News & Updates              4604 non-null   float64
#  16  sentiment_finbert_Semiconductor & Chip Industry News  4604 non-null   float64
#  17  total_count_CEO & Influencer News                     4604 non-null   float64
#  18  total_count_Corporate Earnings & Financials           4604 non-null   float64
#  19  total_count_Corporate Strategy & Growth               4604 non-null   float64
#  20  total_count_Economic Indicators & Fed Policy          4604 non-null   float64
#  21  total_count_General Business & News Reporting         4604 non-null   float64
#  22  total_count_Geopolitical & Trade News                 4604 non-null   float64
#  23  total_count_Innovation & Future Tech                  4604 non-null   float64
#  24  total_count_Investment & Hedge Fund Activity          4604 non-null   float64
#  25  total_count_Investment Analysis & Strategy            4604 non-null   float64
#  26  total_count_Layoffs & Corporate Restructuring         4604 non-null   float64
#  27  total_count_Legal & Regulatory Changes                4604 non-null   float64
#  28  total_count_Market Movements & Trading News           4604 non-null   float64
#  29  total_count_Mergers, Acquisitions & Deals             4604 non-null   float64
#  30  total_count_Product News & Updates                    4604 non-null   float64
#  31  total_count_Semiconductor & Chip Industry News        4604 non-null   float64
#  32  date                                                  4583 non-null   datetime64[ns]
#  33  day_start_value                                       4583 non-null   float64
#  34  day_max_value                                         4583 non-null   float64
#  35  day_min_value                                         4583 non-null   float64
#  36  day_end_value                                         4583 non-null   float64
#  37  day_end_raw_close                                     4583 non-null   float64
#  38  ret_1d                                                4583 non-null   float64
#  39  ret_log_1d                                            4583 non-null   float64
#  40  ret_5d                                                4583 non-null   float64
#  41  ret_log_5d                                            4583 non-null   float64
#  42  ret_10d                                               4583 non-null   float64
#  43  ret_log_10d                                           4583 non-null   float64
#  44  ret_21d                                               4583 non-null   float64
#  45  ret_log_21d                                           4583 non-null   float64
#  46  market_day_start_value                                4583 non-null   float64
#  47  market_day_max_value                                  4583 non-null   float64
#  48  market_day_min_value                                  4583 non-null   float64
#  49  market_day_end_value                                  4583 non-null   float64
#  50  market_day_end_raw_close                              4583 non-null   float64
#  51  market_ret_1d                                         4583 non-null   float64
#  52  market_ret_log_1d                                     4583 non-null   float64
#  53  market_ret_5d                                         4583 non-null   float64
#  54  market_ret_log_5d                                     4583 non-null   float64
#  55  market_ret_10d                                        4583 non-null   float64
#  56  market_ret_log_10d                                    4583 non-null   float64
#  57  market_ret_21d                                        4583 non-null   float64
#  58  market_ret_log_21d                                    4583 non-null   float64
# dtypes: datetime64[ns](2), float64(56), object(1)
# memory usage: 2.1+ MB
# None
#    symbol_query final_date_for_news  sentiment_finbert_CEO & Influencer News  \
# 0       AAPL.US          2023-01-03                                 0.102018
# 1       AAPL.US          2023-01-04                                 0.295232
# 2       AAPL.US          2023-01-05                                -0.003781
# 3       AAPL.US          2023-01-06                                 0.339910
# 4       AAPL.US          2023-01-09                                 0.402631
# 5       AAPL.US          2023-01-10                                 0.235297
# 6       AAPL.US          2023-01-11                                 0.233529
# 7       AAPL.US          2023-01-12                                 0.557647
# 8       AAPL.US          2023-01-13                                 0.513775
# 9       AAPL.US          2023-01-17                                 0.345622
# 10      AAPL.US          2023-01-18                                 0.082826
# 11      AAPL.US          2023-01-19                                -0.019924
# 12      AAPL.US          2023-01-20                                 0.591900
# 13      AAPL.US          2023-01-23                                 0.365973
# 14      AAPL.US          2023-01-24                                 0.473781
# 15      AAPL.US          2023-01-25                                 0.375805
# 16      AAPL.US          2023-01-26                                 0.001101
# 17      AAPL.US          2023-01-27                                -0.473685
# 18      AAPL.US          2023-01-30                                 0.219656
# 19      AAPL.US          2023-01-31                                -0.025006
#
#     sentiment_finbert_Corporate Earnings & Financials  \
# 0                                            0.006831
# 1                                            0.004108
# 2                                           -0.020834
# 3                                            0.006405
# 4                                            0.000000
# 5                                           -0.087694
# 6                                            0.005111
# 7                                           -0.939582
# 8                                            0.027287
# 9                                            0.000000
# 10                                          -0.744709
# 11                                           0.000000
# 12                                           0.000000
# 13                                          -0.148073
# 14                                          -0.720536
# 15                                           0.000151
# 16                                           0.009212
# 17                                           0.000000
# 18                                          -0.097238
# 19                                           0.065152
#
#     sentiment_finbert_Corporate Strategy & Growth  \
# 0                                        0.011222
# 1                                        0.105869
# 2                                        0.032395
# 3                                       -0.081714
# 4                                        0.592804
# 5                                        0.171762
# 6                                        0.000000
# 7                                        0.890311
# 8                                        0.000000
# 9                                       -0.050851
# 10                                      -0.782859
# 11                                       0.111754
# 12                                       0.000000
# 13                                       0.864176
# 14                                      -0.576809
# 15                                       0.000000
# 16                                       0.112200
# 17                                       0.360195
# 18                                       0.423943
# 19                                       0.192734
#
#     sentiment_finbert_Economic Indicators & Fed Policy  \
# 0                                            0.005128
# 1                                           -0.028463
# 2                                            0.011563
# 3                                           -0.328843
# 4                                           -0.002143
# 5                                           -0.230516
# 6                                           -0.397814
# 7                                            0.000000
# 8                                            0.000000
# 9                                           -0.012620
# 10                                          -0.002962
# 11                                           0.005931
# 12                                           0.000000
# 13                                          -0.922710
# 14                                          -0.033022
# 15                                          -0.002199
# 16                                           0.000000
# 17                                           0.000000
# 18                                          -0.128851
# 19                                          -0.146749
#
#     sentiment_finbert_General Business & News Reporting  \
# 0                                            0.000000
# 1                                            0.187918
# 2                                            0.000000
# 3                                            0.000000
# 4                                            0.000000
# 5                                            0.000000
# 6                                           -0.341970
# 7                                            0.435846
# 8                                            0.765312
# 9                                            0.154174
# 10                                           0.000000
# 11                                           0.000000
# 12                                           0.000000
# 13                                           0.607246
# 14                                           0.000000
# 15                                          -0.045410
# 16                                           0.000000
# 17                                           0.000000
# 18                                           0.452063
# 19                                           0.000000
#
#     sentiment_finbert_Geopolitical & Trade News  \
# 0                                      0.228387
# 1                                     -0.254930
# 2                                      0.050943
# 3                                     -0.174730
# 4                                      0.123715
# 5                                      0.009193
# 6                                      0.384314
# 7                                      0.106334
# 8                                     -0.028932
# 9                                      0.147139
# 10                                    -0.246281
# 11                                     0.068567
# 12                                     0.318851
# 13                                     0.000000
# 14                                     0.381713
# 15                                     0.023421
# 16                                     0.452576
# 17                                     0.060356
# 18                                     0.032659
# 19                                     0.048767
#
#     sentiment_finbert_Innovation & Future Tech  \
# 0                                     0.221808
# 1                                     0.246283
# 2                                    -0.000648
# 3                                     0.095464
# 4                                     0.017661
# 5                                    -0.154745
# 6                                    -0.072696
# 7                                     0.129372
# 8                                     0.000000
# 9                                     0.649367
# 10                                    0.242484
# 11                                    0.111665
# 12                                    0.000000
# 13                                    0.632357
# 14                                    0.548207
# 15                                   -0.831483
# 16                                    0.000000
# 17                                    0.000000
# 18                                    0.801467
# 19                                    0.713974
#
#     sentiment_finbert_Investment & Hedge Fund Activity  ...  \
# 0                                            0.380450   ...
# 1                                            0.000000   ...
# 2                                           -0.484566   ...
# 3                                           -0.058425   ...
# 4                                            0.000000   ...
# 5                                            0.000000   ...
# 6                                           -0.915715   ...
# 7                                            0.000000   ...
# 8                                           -0.306461   ...
# 9                                            0.194337   ...
# 10                                           0.163108   ...
# 11                                           0.000000   ...
# 12                                           0.319303   ...
# 13                                          -0.323024   ...
# 14                                           0.141040   ...
# 15                                          -0.008723   ...
# 16                                          -0.903925   ...
# 17                                           0.303430   ...
# 18                                          -0.014153   ...
# 19                                           0.001761   ...
#
#     market_day_end_value  market_day_end_raw_close  market_ret_1d  \
# 0             367.150726                380.820007      -0.004210
# 1             369.985291                383.760010       0.007720
# 2             365.762451                379.380005      -0.011413
# 3             374.150116                388.079987       0.022932
# 4             373.938049                387.859985      -0.000567
# 5             376.560394                390.579987       0.007013
# 6             381.323120                395.519989       0.012648
# 7             382.711426                396.959991       0.003641
# 8             384.196106                398.500000       0.003880
# 9             383.492371                397.769989      -0.001832
# 10            377.437775                391.489990      -0.015788
# 11            374.690094                388.640015      -0.007280
# 12            381.670227                395.880005       0.018629
# 13            386.249695                400.630005       0.011999
# 14            385.835175                400.200012      -0.001073
# 15            385.979797                400.350006       0.000375
# 16            390.221771                404.750000       0.010990
# 17            391.118378                405.679993       0.002298
# 18            386.211121                400.589996      -0.012547
# 19            391.889740                406.480011       0.014703
#
#     market_ret_log_1d  market_ret_5d  market_ret_log_5d  market_ret_10d  \
# 0           -0.004219      -0.005458          -0.005473       -0.006392
# 1            0.007691       0.006188           0.006169        0.009842
# 2           -0.011479       0.007221           0.007195       -0.003048
# 3            0.022673       0.012101           0.012028        0.004790
# 4           -0.000567       0.014199           0.014099        0.018754
# 5            0.006988       0.025629           0.025306        0.020031
# 6            0.012569       0.030644           0.030184        0.037021
# 7            0.003634       0.046339           0.045297        0.053895
# 8            0.003872       0.026850           0.026496        0.039276
# 9           -0.001834       0.025550           0.025230        0.040112
# 10          -0.015914       0.002330           0.002327        0.028018
# 11          -0.007306      -0.017395          -0.017548        0.012716
# 12           0.018458      -0.002721          -0.002724        0.043492
# 13           0.011927       0.005345           0.005331        0.032339
# 14          -0.001074       0.006109           0.006091        0.031816
# 15           0.000375       0.022632           0.022379        0.025014
# 16           0.010930       0.041452           0.040616        0.023336
# 17           0.002295       0.024755           0.024454        0.021967
# 18          -0.012626      -0.000100          -0.000100        0.005245
# 19           0.014596       0.015692           0.015570        0.021897
#
#     market_ret_log_10d  market_ret_21d  market_ret_log_21d
# 0            -0.006413       -0.065197           -0.067420
# 1             0.009794       -0.056892           -0.058575
# 2            -0.003053       -0.050577           -0.051901
# 3             0.004778       -0.014600           -0.014708
# 4             0.018580       -0.013481           -0.013572
# 5             0.019833       -0.014284           -0.014387
# 6             0.036353        0.005696            0.005680
# 7             0.052493       -0.004988           -0.005001
# 8             0.038524       -0.008632           -0.008670
# 9             0.039328       -0.004081           -0.004089
# 10            0.027633        0.004774            0.004762
# 11            0.012636        0.014011            0.013914
# 12            0.042573        0.041735            0.040887
# 13            0.031827        0.052793            0.051447
# 14            0.031320        0.036170            0.035531
# 15            0.024706        0.051560            0.050275
# 16            0.023068        0.057037            0.055470
# 17            0.021729        0.063660            0.061716
# 18            0.005231        0.063532            0.061596
# 19            0.021661        0.060088            0.058352
#
# [20 rows x 59 columns]

# %%
read_df['total_news'] = read_df[['total_count_CEO & Influencer News',
       'total_count_Corporate Earnings & Financials',
       'total_count_Corporate Strategy & Growth',
       'total_count_Economic Indicators & Fed Policy',
       'total_count_General Business & News Reporting',
       'total_count_Geopolitical & Trade News',
       'total_count_Innovation & Future Tech',
       'total_count_Investment & Hedge Fund Activity',
       'total_count_Investment Analysis & Strategy',
       'total_count_Layoffs & Corporate Restructuring',
       'total_count_Legal & Regulatory Changes',
       'total_count_Market Movements & Trading News',
       'total_count_Mergers, Acquisitions & Deals',
       'total_count_Product News & Updates',
       'total_count_Semiconductor & Chip Industry News']].sum(axis=1)

read_df
# Out:
#      symbol_query final_date_for_news  \
# 0         AAPL.US          2023-01-03
# 1         AAPL.US          2023-01-04
# 2         AAPL.US          2023-01-05
# 3         AAPL.US          2023-01-06
# 4         AAPL.US          2023-01-09
# ...           ...                 ...
# 4599      TSLA.US          2025-10-28
# 4600      TSLA.US          2025-10-29
# 4601      TSLA.US          2025-10-30
# 4602      TSLA.US          2025-10-31
# 4603      TSLA.US          2025-11-03
#
#       sentiment_finbert_CEO & Influencer News  \
# 0                                    0.102018
# 1                                    0.295232
# 2                                   -0.003781
# 3                                    0.339910
# 4                                    0.402631
# ...                                       ...
# 4599                                 0.422765
# 4600                                 0.710269
# 4601                                 0.255318
# 4602                                 0.000000
# 4603                                 0.000000
#
#       sentiment_finbert_Corporate Earnings & Financials  \
# 0                                              0.006831
# 1                                              0.004108
# 2                                             -0.020834
# 3                                              0.006405
# 4                                              0.000000
# ...                                                 ...
# 4599                                          -0.769021
# 4600                                          -0.034526
# 4601                                          -0.450931
# 4602                                           0.015151
# 4603                                           0.000000
#
#       sentiment_finbert_Corporate Strategy & Growth  \
# 0                                          0.011222
# 1                                          0.105869
# 2                                          0.032395
# 3                                         -0.081714
# 4                                          0.592804
# ...                                             ...
# 4599                                      -0.687290
# 4600                                       0.000000
# 4601                                       0.000000
# 4602                                       0.000000
# 4603                                       0.000000
#
#       sentiment_finbert_Economic Indicators & Fed Policy  \
# 0                                              0.005128
# 1                                             -0.028463
# 2                                              0.011563
# 3                                             -0.328843
# 4                                             -0.002143
# ...                                                 ...
# 4599                                           0.000000
# 4600                                           0.000000
# 4601                                           0.000000
# 4602                                           0.000000
# 4603                                           0.000000
#
#       sentiment_finbert_General Business & News Reporting  \
# 0                                              0.000000
# 1                                              0.187918
# 2                                              0.000000
# 3                                              0.000000
# 4                                              0.000000
# ...                                                 ...
# 4599                                           0.506782
# 4600                                           0.868544
# 4601                                           0.000000
# 4602                                           0.000000
# 4603                                           0.857611
#
#       sentiment_finbert_Geopolitical & Trade News  \
# 0                                        0.228387
# 1                                       -0.254930
# 2                                        0.050943
# 3                                       -0.174730
# 4                                        0.123715
# ...                                           ...
# 4599                                    -0.032127
# 4600                                     0.114943
# 4601                                     0.001063
# 4602                                     0.552707
# 4603                                     0.000000
#
#       sentiment_finbert_Innovation & Future Tech  \
# 0                                       0.221808
# 1                                       0.246283
# 2                                      -0.000648
# 3                                       0.095464
# 4                                       0.017661
# ...                                          ...
# 4599                                    0.000000
# 4600                                    0.000000
# 4601                                    0.000000
# 4602                                    0.000000
# 4603                                    0.000000
#
#       sentiment_finbert_Investment & Hedge Fund Activity  ...  \
# 0                                              0.380450   ...
# 1                                              0.000000   ...
# 2                                             -0.484566   ...
# 3                                             -0.058425   ...
# 4                                              0.000000   ...
# ...                                                 ...   ...
# 4599                                           0.610859   ...
# 4600                                           0.000000   ...
# 4601                                           0.000000   ...
# 4602                                           0.000000   ...
# 4603                                           0.000000   ...
#
#       market_day_end_raw_close  market_ret_1d  market_ret_log_1d  \
# 0                   380.820007      -0.004210          -0.004219
# 1                   383.760010       0.007720           0.007691
# 2                   379.380005      -0.011413          -0.011479
# 3                   388.079987       0.022932           0.022673
# 4                   387.859985      -0.000567          -0.000567
# ...                        ...            ...                ...
# 4599                687.059998       0.002656           0.002652
# 4600                687.390015       0.000480           0.000480
# 4601                679.830017      -0.010998          -0.011059
# 4602                       NaN            NaN                NaN
# 4603                       NaN            NaN                NaN
#
#       market_ret_5d  market_ret_log_5d  market_ret_10d  market_ret_log_10d  \
# 0         -0.005458          -0.005473       -0.006392           -0.006413
# 1          0.006188           0.006169        0.009842            0.009794
# 2          0.007221           0.007195       -0.003048           -0.003053
# 3          0.012101           0.012028        0.004790            0.004778
# 4          0.014199           0.014099        0.018754            0.018580
# ...             ...                ...             ...                 ...
# 4599       0.023492           0.023220        0.037495            0.036809
# 4600       0.029335           0.028913        0.033405            0.032859
# 4601       0.012013           0.011942        0.029048            0.028634
# 4602            NaN                NaN             NaN                 NaN
# 4603            NaN                NaN             NaN                 NaN
#
#       market_ret_21d  market_ret_log_21d  total_news
# 0          -0.065197           -0.067420        29.0
# 1          -0.056892           -0.058575        51.0
# 2          -0.050577           -0.051901        26.0
# 3          -0.014600           -0.014708        23.0
# 4          -0.013481           -0.013572        30.0
# ...              ...                 ...         ...
# 4599        0.035228            0.034622        27.0
# 4600        0.031838            0.031342        16.0
# 4601        0.017024            0.016881        15.0
# 4602             NaN                 NaN         5.0
# 4603             NaN                 NaN         1.0
#
# [4604 rows x 60 columns]

# %%
col_list = ['total_count_CEO & Influencer News',
       'total_count_Corporate Earnings & Financials',
       'total_count_Corporate Strategy & Growth',
       'total_count_Economic Indicators & Fed Policy',
       'total_count_General Business & News Reporting',
       'total_count_Geopolitical & Trade News',
       'total_count_Innovation & Future Tech',
       'total_count_Investment & Hedge Fund Activity',
       'total_count_Investment Analysis & Strategy',
       'total_count_Layoffs & Corporate Restructuring',
       'total_count_Legal & Regulatory Changes',
       'total_count_Market Movements & Trading News',
       'total_count_Mergers, Acquisitions & Deals',
       'total_count_Product News & Updates',
       'total_count_Semiconductor & Chip Industry News'
]

pc_counts = read_df.copy()

for col in col_list:
  pc_counts[col] = (pc_counts[col]/pc_counts['total_news'])

pc_counts[['total_count_CEO & Influencer News',
       'total_count_Corporate Earnings & Financials',
       'total_count_Corporate Strategy & Growth',
       'total_count_Economic Indicators & Fed Policy',
       'total_count_General Business & News Reporting',
       'total_count_Geopolitical & Trade News',
       'total_count_Innovation & Future Tech',
       'total_count_Investment & Hedge Fund Activity',
       'total_count_Investment Analysis & Strategy',
       'total_count_Layoffs & Corporate Restructuring',
       'total_count_Legal & Regulatory Changes',
       'total_count_Market Movements & Trading News',
       'total_count_Mergers, Acquisitions & Deals',
       'total_count_Product News & Updates',
       'total_count_Semiconductor & Chip Industry News', 'total_news'
]]
# Out:
#       total_count_CEO & Influencer News  \
# 0                              0.206897
# 1                              0.196078
# 2                              0.115385
# 3                              0.217391
# 4                              0.266667
# ...                                 ...
# 4599                           0.148148
# 4600                           0.437500
# 4601                           0.200000
# 4602                           0.000000
# 4603                           0.000000
#
#       total_count_Corporate Earnings & Financials  \
# 0                                        0.034483
# 1                                        0.156863
# 2                                        0.076923
# 3                                        0.130435
# 4                                        0.000000
# ...                                           ...
# 4599                                     0.111111
# 4600                                     0.062500
# 4601                                     0.266667
# 4602                                     0.200000
# 4603                                     0.000000
#
#       total_count_Corporate Strategy & Growth  \
# 0                                    0.034483
# 1                                    0.039216
# 2                                    0.038462
# 3                                    0.043478
# 4                                    0.100000
# ...                                       ...
# 4599                                 0.037037
# 4600                                 0.000000
# 4601                                 0.000000
# 4602                                 0.000000
# 4603                                 0.000000
#
#       total_count_Economic Indicators & Fed Policy  \
# 0                                         0.034483
# 1                                         0.156863
# 2                                         0.038462
# 3                                         0.086957
# 4                                         0.066667
# ...                                            ...
# 4599                                      0.000000
# 4600                                      0.000000
# 4601                                      0.000000
# 4602                                      0.000000
# 4603                                      0.000000
#
#       total_count_General Business & News Reporting  \
# 0                                          0.000000
# 1                                          0.039216
# 2                                          0.000000
# 3                                          0.000000
# 4                                          0.000000
# ...                                             ...
# 4599                                       0.111111
# 4600                                       0.062500
# 4601                                       0.000000
# 4602                                       0.000000
# 4603                                       1.000000
#
#       total_count_Geopolitical & Trade News  \
# 0                                  0.206897
# 1                                  0.058824
# 2                                  0.115385
# 3                                  0.043478
# 4                                  0.300000
# ...                                     ...
# 4599                               0.148148
# 4600                               0.187500
# 4601                               0.066667
# 4602                               0.200000
# 4603                               0.000000
#
#       total_count_Innovation & Future Tech  \
# 0                                 0.137931
# 1                                 0.058824
# 2                                 0.038462
# 3                                 0.130435
# 4                                 0.033333
# ...                                    ...
# 4599                              0.000000
# 4600                              0.000000
# 4601                              0.000000
# 4602                              0.000000
# 4603                              0.000000
#
#       total_count_Investment & Hedge Fund Activity  \
# 0                                         0.137931
# 1                                         0.000000
# 2                                         0.038462
# 3                                         0.086957
# 4                                         0.000000
# ...                                            ...
# 4599                                      0.037037
# 4600                                      0.000000
# 4601                                      0.000000
# 4602                                      0.000000
# 4603                                      0.000000
#
#       total_count_Investment Analysis & Strategy  \
# 0                                       0.034483
# 1                                       0.019608
# 2                                       0.000000
# 3                                       0.000000
# 4                                       0.000000
# ...                                          ...
# 4599                                    0.259259
# 4600                                    0.250000
# 4601                                    0.266667
# 4602                                    0.200000
# 4603                                    0.000000
#
#       total_count_Layoffs & Corporate Restructuring  \
# 0                                          0.034483
# 1                                          0.058824
# 2                                          0.000000
# 3                                          0.086957
# 4                                          0.000000
# ...                                             ...
# 4599                                       0.000000
# 4600                                       0.000000
# 4601                                       0.000000
# 4602                                       0.000000
# 4603                                       0.000000
#
#       total_count_Legal & Regulatory Changes  \
# 0                                   0.000000
# 1                                   0.000000
# 2                                   0.038462
# 3                                   0.000000
# 4                                   0.000000
# ...                                      ...
# 4599                                0.000000
# 4600                                0.000000
# 4601                                0.000000
# 4602                                0.000000
# 4603                                0.000000
#
#       total_count_Market Movements & Trading News  \
# 0                                        0.068966
# 1                                        0.196078
# 2                                        0.115385
# 3                                        0.130435
# 4                                        0.133333
# ...                                           ...
# 4599                                     0.000000
# 4600                                     0.000000
# 4601                                     0.000000
# 4602                                     0.000000
# 4603                                     0.000000
#
#       total_count_Mergers, Acquisitions & Deals  \
# 0                                      0.000000
# 1                                      0.000000
# 2                                      0.000000
# 3                                      0.000000
# 4                                      0.000000
# ...                                         ...
# 4599                                   0.037037
# 4600                                   0.000000
# 4601                                   0.133333
# 4602                                   0.200000
# 4603                                   0.000000
#
#       total_count_Product News & Updates  \
# 0                               0.068966
# 1                               0.019608
# 2                               0.384615
# 3                               0.043478
# 4                               0.100000
# ...                                  ...
# 4599                            0.037037
# 4600                            0.000000
# 4601                            0.066667
# 4602                            0.200000
# 4603                            0.000000
#
#       total_count_Semiconductor & Chip Industry News  total_news
# 0                                           0.000000        29.0
# 1                                           0.000000        51.0
# 2                                           0.000000        26.0
# 3                                           0.000000        23.0
# 4                                           0.000000        30.0
# ...                                              ...         ...
# 4599                                        0.074074        27.0
# 4600                                        0.000000        16.0
# 4601                                        0.000000        15.0
# 4602                                        0.000000         5.0
# 4603                                        0.000000         1.0
#
# [4604 rows x 16 columns]

# %%
pc_counts['total_news'].sum()
# Out:
# np.float64(101346.0)

# %%
pc_counts.columns
# Out:
# Index(['symbol_query', 'final_date_for_news',
#        'sentiment_finbert_CEO & Influencer News',
#        'sentiment_finbert_Corporate Earnings & Financials',
#        'sentiment_finbert_Corporate Strategy & Growth',
#        'sentiment_finbert_Economic Indicators & Fed Policy',
#        'sentiment_finbert_General Business & News Reporting',
#        'sentiment_finbert_Geopolitical & Trade News',
#        'sentiment_finbert_Innovation & Future Tech',
#        'sentiment_finbert_Investment & Hedge Fund Activity',
#        'sentiment_finbert_Investment Analysis & Strategy',
#        'sentiment_finbert_Layoffs & Corporate Restructuring',
#        'sentiment_finbert_Legal & Regulatory Changes',
#        'sentiment_finbert_Market Movements & Trading News',
#        'sentiment_finbert_Mergers, Acquisitions & Deals',
#        'sentiment_finbert_Product News & Updates',
#        'sentiment_finbert_Semiconductor & Chip Industry News',
#        'total_count_CEO & Influencer News',
#        'total_count_Corporate Earnings & Financials',
#        'total_count_Corporate Strategy & Growth',
#        'total_count_Economic Indicators & Fed Policy',
#        'total_count_General Business & News Reporting',
#        'total_count_Geopolitical & Trade News',
#        'total_count_Innovation & Future Tech',
#        'total_count_Investment & Hedge Fund Activity',
#        'total_count_Investment Analysis & Strategy',
#        'total_count_Layoffs & Corporate Restructuring',
#        'total_count_Legal & Regulatory Changes',
#        'total_count_Market Movements & Trading News',
#        'total_count_Mergers, Acquisitions & Deals',
#        'total_count_Product News & Updates',
#        'total_count_Semiconductor & Chip Industry News', 'date',
#        'day_start_value', 'day_max_value', 'day_min_value', 'day_end_value',
#        'day_end_raw_close', 'ret_1d', 'ret_log_1d', 'ret_5d', 'ret_log_5d',
#        'ret_10d', 'ret_log_10d', 'ret_21d', 'ret_log_21d',
#        'market_day_start_value', 'market_day_max_value',
#        'market_day_min_value', 'market_day_end_value',
#        'market_day_end_raw_close', 'market_ret_1d', 'market_ret_log_1d',
#        'market_ret_5d', 'market_ret_log_5d', 'market_ret_10d',
#        'market_ret_log_10d', 'market_ret_21d', 'market_ret_log_21d',
#        'total_news'],
#       dtype='object')

# %%
import numpy as np

avg_sentiment_df = pc_counts.copy()

avg_sentiment_df['day_sentiment'] = avg_sentiment_df[['sentiment_finbert_CEO & Influencer News',
       'sentiment_finbert_Corporate Earnings & Financials',
       'sentiment_finbert_Corporate Strategy & Growth',
       'sentiment_finbert_Economic Indicators & Fed Policy',
       'sentiment_finbert_General Business & News Reporting',
       'sentiment_finbert_Geopolitical & Trade News',
       'sentiment_finbert_Innovation & Future Tech',
       'sentiment_finbert_Investment & Hedge Fund Activity',
       'sentiment_finbert_Investment Analysis & Strategy',
       'sentiment_finbert_Layoffs & Corporate Restructuring',
       'sentiment_finbert_Legal & Regulatory Changes',
       'sentiment_finbert_Market Movements & Trading News',
       'sentiment_finbert_Mergers, Acquisitions & Deals',
       'sentiment_finbert_Product News & Updates',
       'sentiment_finbert_Semiconductor & Chip Industry News']].replace(0, np.nan).mean(axis=1)

avg_sentiment_df
# Out:
#      symbol_query final_date_for_news  \
# 0         AAPL.US          2023-01-03
# 1         AAPL.US          2023-01-04
# 2         AAPL.US          2023-01-05
# 3         AAPL.US          2023-01-06
# 4         AAPL.US          2023-01-09
# ...           ...                 ...
# 4599      TSLA.US          2025-10-28
# 4600      TSLA.US          2025-10-29
# 4601      TSLA.US          2025-10-30
# 4602      TSLA.US          2025-10-31
# 4603      TSLA.US          2025-11-03
#
#       sentiment_finbert_CEO & Influencer News  \
# 0                                    0.102018
# 1                                    0.295232
# 2                                   -0.003781
# 3                                    0.339910
# 4                                    0.402631
# ...                                       ...
# 4599                                 0.422765
# 4600                                 0.710269
# 4601                                 0.255318
# 4602                                 0.000000
# 4603                                 0.000000
#
#       sentiment_finbert_Corporate Earnings & Financials  \
# 0                                              0.006831
# 1                                              0.004108
# 2                                             -0.020834
# 3                                              0.006405
# 4                                              0.000000
# ...                                                 ...
# 4599                                          -0.769021
# 4600                                          -0.034526
# 4601                                          -0.450931
# 4602                                           0.015151
# 4603                                           0.000000
#
#       sentiment_finbert_Corporate Strategy & Growth  \
# 0                                          0.011222
# 1                                          0.105869
# 2                                          0.032395
# 3                                         -0.081714
# 4                                          0.592804
# ...                                             ...
# 4599                                      -0.687290
# 4600                                       0.000000
# 4601                                       0.000000
# 4602                                       0.000000
# 4603                                       0.000000
#
#       sentiment_finbert_Economic Indicators & Fed Policy  \
# 0                                              0.005128
# 1                                             -0.028463
# 2                                              0.011563
# 3                                             -0.328843
# 4                                             -0.002143
# ...                                                 ...
# 4599                                           0.000000
# 4600                                           0.000000
# 4601                                           0.000000
# 4602                                           0.000000
# 4603                                           0.000000
#
#       sentiment_finbert_General Business & News Reporting  \
# 0                                              0.000000
# 1                                              0.187918
# 2                                              0.000000
# 3                                              0.000000
# 4                                              0.000000
# ...                                                 ...
# 4599                                           0.506782
# 4600                                           0.868544
# 4601                                           0.000000
# 4602                                           0.000000
# 4603                                           0.857611
#
#       sentiment_finbert_Geopolitical & Trade News  \
# 0                                        0.228387
# 1                                       -0.254930
# 2                                        0.050943
# 3                                       -0.174730
# 4                                        0.123715
# ...                                           ...
# 4599                                    -0.032127
# 4600                                     0.114943
# 4601                                     0.001063
# 4602                                     0.552707
# 4603                                     0.000000
#
#       sentiment_finbert_Innovation & Future Tech  \
# 0                                       0.221808
# 1                                       0.246283
# 2                                      -0.000648
# 3                                       0.095464
# 4                                       0.017661
# ...                                          ...
# 4599                                    0.000000
# 4600                                    0.000000
# 4601                                    0.000000
# 4602                                    0.000000
# 4603                                    0.000000
#
#       sentiment_finbert_Investment & Hedge Fund Activity  ...  market_ret_1d  \
# 0                                              0.380450   ...      -0.004210
# 1                                              0.000000   ...       0.007720
# 2                                             -0.484566   ...      -0.011413
# 3                                             -0.058425   ...       0.022932
# 4                                              0.000000   ...      -0.000567
# ...                                                 ...   ...            ...
# 4599                                           0.610859   ...       0.002656
# 4600                                           0.000000   ...       0.000480
# 4601                                           0.000000   ...      -0.010998
# 4602                                           0.000000   ...            NaN
# 4603                                           0.000000   ...            NaN
#
#       market_ret_log_1d  market_ret_5d  market_ret_log_5d  market_ret_10d  \
# 0             -0.004219      -0.005458          -0.005473       -0.006392
# 1              0.007691       0.006188           0.006169        0.009842
# 2             -0.011479       0.007221           0.007195       -0.003048
# 3              0.022673       0.012101           0.012028        0.004790
# 4             -0.000567       0.014199           0.014099        0.018754
# ...                 ...            ...                ...             ...
# 4599           0.002652       0.023492           0.023220        0.037495
# 4600           0.000480       0.029335           0.028913        0.033405
# 4601          -0.011059       0.012013           0.011942        0.029048
# 4602                NaN            NaN                NaN             NaN
# 4603                NaN            NaN                NaN             NaN
#
#       market_ret_log_10d  market_ret_21d  market_ret_log_21d  total_news  \
# 0              -0.006413       -0.065197           -0.067420        29.0
# 1               0.009794       -0.056892           -0.058575        51.0
# 2              -0.003053       -0.050577           -0.051901        26.0
# 3               0.004778       -0.014600           -0.014708        23.0
# 4               0.018580       -0.013481           -0.013572        30.0
# ...                  ...             ...                 ...         ...
# 4599            0.036809        0.035228            0.034622        27.0
# 4600            0.032859        0.031838            0.031342        16.0
# 4601            0.028634        0.017024            0.016881        15.0
# 4602                 NaN             NaN                 NaN         5.0
# 4603                 NaN             NaN                 NaN         1.0
#
#       day_sentiment
# 0          0.129412
# 1          0.087933
# 2         -0.021794
# 3          0.064575
# 4          0.105967
# ...             ...
# 4599       0.042746
# 4600       0.295392
# 4601       0.066087
# 4602      -0.041702
# 4603       0.857611
#
# [4604 rows x 61 columns]

# %% [markdown]
# # Apple Regressions

# %%
apple_df = avg_sentiment_df.loc[avg_sentiment_df['symbol_query'] == 'MSFT.US',:].copy()
apple_df
# Out:
#      symbol_query final_date_for_news  \
# 2676      MSFT.US          2023-01-03
# 2677      MSFT.US          2023-01-04
# 2678      MSFT.US          2023-01-05
# 2679      MSFT.US          2023-01-06
# 2680      MSFT.US          2023-01-09
# ...           ...                 ...
# 3325      MSFT.US          2025-10-28
# 3326      MSFT.US          2025-10-29
# 3327      MSFT.US          2025-10-30
# 3328      MSFT.US          2025-10-31
# 3329      MSFT.US          2025-11-03
#
#       sentiment_finbert_CEO & Influencer News  \
# 2676                                 0.111051
# 2677                                 0.478465
# 2678                                 0.205051
# 2679                                 0.517990
# 2680                                 0.270507
# ...                                       ...
# 3325                                 0.555036
# 3326                                 0.402426
# 3327                                 0.163271
# 3328                                 0.151147
# 3329                                 0.000000
#
#       sentiment_finbert_Corporate Earnings & Financials  \
# 2676                                           0.000000
# 2677                                          -0.047136
# 2678                                           0.000000
# 2679                                           0.000000
# 2680                                           0.000000
# ...                                                 ...
# 3325                                          -0.577576
# 3326                                          -0.550731
# 3327                                          -0.489574
# 3328                                          -0.668504
# 3329                                           0.000000
#
#       sentiment_finbert_Corporate Strategy & Growth  \
# 2676                                       0.000000
# 2677                                       0.524175
# 2678                                       0.321901
# 2679                                       0.000000
# 2680                                      -0.399397
# ...                                             ...
# 3325                                      -0.033971
# 3326                                       0.129532
# 3327                                      -0.058380
# 3328                                       0.559364
# 3329                                       0.000000
#
#       sentiment_finbert_Economic Indicators & Fed Policy  \
# 2676                                           0.000000
# 2677                                          -0.031575
# 2678                                          -0.028175
# 2679                                           0.003330
# 2680                                           0.000000
# ...                                                 ...
# 3325                                           0.000000
# 3326                                           0.000000
# 3327                                           0.000000
# 3328                                           0.000000
# 3329                                           0.000000
#
#       sentiment_finbert_General Business & News Reporting  \
# 2676                                           0.000000
# 2677                                           0.000000
# 2678                                           0.088447
# 2679                                           0.000000
# 2680                                           0.000000
# ...                                                 ...
# 3325                                           0.528923
# 3326                                           0.389603
# 3327                                           0.505056
# 3328                                           0.480577
# 3329                                           0.753101
#
#       sentiment_finbert_Geopolitical & Trade News  \
# 2676                                    -0.783932
# 2677                                     0.568508
# 2678                                     0.098990
# 2679                                    -0.895080
# 2680                                    -0.045231
# ...                                           ...
# 3325                                    -0.404822
# 3326                                    -0.385564
# 3327                                    -0.099026
# 3328                                    -0.157083
# 3329                                     0.008595
#
#       sentiment_finbert_Innovation & Future Tech  \
# 2676                                    0.007867
# 2677                                    0.575411
# 2678                                   -0.525969
# 2679                                    0.755901
# 2680                                   -0.028778
# ...                                          ...
# 3325                                    0.543984
# 3326                                    0.640473
# 3327                                    0.035427
# 3328                                   -0.557741
# 3329                                    0.000000
#
#       sentiment_finbert_Investment & Hedge Fund Activity  ...  market_ret_1d  \
# 2676                                           0.000000   ...      -0.004210
# 2677                                           0.268354   ...       0.007720
# 2678                                           0.423550   ...      -0.011413
# 2679                                           0.112854   ...       0.022932
# 2680                                           0.000000   ...      -0.000567
# ...                                                 ...   ...            ...
# 3325                                           0.287950   ...       0.002656
# 3326                                          -0.012738   ...       0.000480
# 3327                                          -0.058294   ...      -0.010998
# 3328                                           0.000000   ...            NaN
# 3329                                           0.000000   ...            NaN
#
#       market_ret_log_1d  market_ret_5d  market_ret_log_5d  market_ret_10d  \
# 2676          -0.004219      -0.005458          -0.005473       -0.006392
# 2677           0.007691       0.006188           0.006169        0.009842
# 2678          -0.011479       0.007221           0.007195       -0.003048
# 2679           0.022673       0.012101           0.012028        0.004790
# 2680          -0.000567       0.014199           0.014099        0.018754
# ...                 ...            ...                ...             ...
# 3325           0.002652       0.023492           0.023220        0.037495
# 3326           0.000480       0.029335           0.028913        0.033405
# 3327          -0.011059       0.012013           0.011942        0.029048
# 3328                NaN            NaN                NaN             NaN
# 3329                NaN            NaN                NaN             NaN
#
#       market_ret_log_10d  market_ret_21d  market_ret_log_21d  total_news  \
# 2676           -0.006413       -0.065197           -0.067420        10.0
# 2677            0.009794       -0.056892           -0.058575        28.0
# 2678           -0.003053       -0.050577           -0.051901        36.0
# 2679            0.004778       -0.014600           -0.014708        15.0
# 2680            0.018580       -0.013481           -0.013572        10.0
# ...                  ...             ...                 ...         ...
# 3325            0.036809        0.035228            0.034622       130.0
# 3326            0.032859        0.031838            0.031342       164.0
# 3327            0.028634        0.017024            0.016881       173.0
# 3328                 NaN             NaN                 NaN        96.0
# 3329                 NaN             NaN                 NaN         3.0
#
#       day_sentiment
# 2676      -0.016513
# 2677       0.219938
# 2678       0.217139
# 2679       0.164615
# 2680       0.061689
# ...             ...
# 3325       0.118293
# 3326       0.091647
# 3327      -0.019198
# 3328      -0.167012
# 3329       0.380848
#
# [654 rows x 61 columns]

# %%
apple_df_train = apple_df.loc[apple_df['date'] < '2025-06-01',:].copy()

apple_df_test = apple_df.loc[apple_df['date'] >= '2025-06-01', :].copy()

display(apple_df_train.head())
display(apple_df_train.shape)
display(apple_df_test.head())
display(apple_df_test.shape)
# Out:
#      symbol_query final_date_for_news  \
# 2676      MSFT.US          2023-01-03
# 2677      MSFT.US          2023-01-04
# 2678      MSFT.US          2023-01-05
# 2679      MSFT.US          2023-01-06
# 2680      MSFT.US          2023-01-09
#
#       sentiment_finbert_CEO & Influencer News  \
# 2676                                 0.111051
# 2677                                 0.478465
# 2678                                 0.205051
# 2679                                 0.517990
# 2680                                 0.270507
#
#       sentiment_finbert_Corporate Earnings & Financials  \
# 2676                                           0.000000
# 2677                                          -0.047136
# 2678                                           0.000000
# 2679                                           0.000000
# 2680                                           0.000000
#
#       sentiment_finbert_Corporate Strategy & Growth  \
# 2676                                       0.000000
# 2677                                       0.524175
# 2678                                       0.321901
# 2679                                       0.000000
# 2680                                      -0.399397
#
#       sentiment_finbert_Economic Indicators & Fed Policy  \
# 2676                                           0.000000
# 2677                                          -0.031575
# 2678                                          -0.028175
# 2679                                           0.003330
# 2680                                           0.000000
#
#       sentiment_finbert_General Business & News Reporting  \
# 2676                                           0.000000
# 2677                                           0.000000
# 2678                                           0.088447
# 2679                                           0.000000
# 2680                                           0.000000
#
#       sentiment_finbert_Geopolitical & Trade News  \
# 2676                                    -0.783932
# 2677                                     0.568508
# 2678                                     0.098990
# 2679                                    -0.895080
# 2680                                    -0.045231
#
#       sentiment_finbert_Innovation & Future Tech  \
# 2676                                    0.007867
# 2677                                    0.575411
# 2678                                   -0.525969
# 2679                                    0.755901
# 2680                                   -0.028778
#
#       sentiment_finbert_Investment & Hedge Fund Activity  ...  market_ret_1d  \
# 2676                                           0.000000   ...      -0.004210
# 2677                                           0.268354   ...       0.007720
# 2678                                           0.423550   ...      -0.011413
# 2679                                           0.112854   ...       0.022932
# 2680                                           0.000000   ...      -0.000567
#
#       market_ret_log_1d  market_ret_5d  market_ret_log_5d  market_ret_10d  \
# 2676          -0.004219      -0.005458          -0.005473       -0.006392
# 2677           0.007691       0.006188           0.006169        0.009842
# 2678          -0.011479       0.007221           0.007195       -0.003048
# 2679           0.022673       0.012101           0.012028        0.004790
# 2680          -0.000567       0.014199           0.014099        0.018754
#
#       market_ret_log_10d  market_ret_21d  market_ret_log_21d  total_news  \
# 2676           -0.006413       -0.065197           -0.067420        10.0
# 2677            0.009794       -0.056892           -0.058575        28.0
# 2678           -0.003053       -0.050577           -0.051901        36.0
# 2679            0.004778       -0.014600           -0.014708        15.0
# 2680            0.018580       -0.013481           -0.013572        10.0
#
#       day_sentiment
# 2676      -0.016513
# 2677       0.219938
# 2678       0.217139
# 2679       0.164615
# 2680       0.061689
#
# [5 rows x 61 columns]
# (596, 61)
#      symbol_query final_date_for_news  \
# 3273      MSFT.US          2025-06-02
# 3274      MSFT.US          2025-06-03
# 3275      MSFT.US          2025-06-04
# 3276      MSFT.US          2025-06-05
# 3277      MSFT.US          2025-06-06
#
#       sentiment_finbert_CEO & Influencer News  \
# 3273                                 0.363579
# 3274                                 0.857679
# 3275                                -0.681036
# 3276                                 0.325587
# 3277                                 0.625829
#
#       sentiment_finbert_Corporate Earnings & Financials  \
# 3273                                           0.000000
# 3274                                          -0.427940
# 3275                                          -0.507475
# 3276                                          -0.913353
# 3277                                          -0.298326
#
#       sentiment_finbert_Corporate Strategy & Growth  \
# 3273                                      -0.018180
# 3274                                       0.000000
# 3275                                       0.000000
# 3276                                       0.463495
# 3277                                      -0.896047
#
#       sentiment_finbert_Economic Indicators & Fed Policy  \
# 3273                                                0.0
# 3274                                                0.0
# 3275                                                0.0
# 3276                                                0.0
# 3277                                                0.0
#
#       sentiment_finbert_General Business & News Reporting  \
# 3273                                           0.000000
# 3274                                           0.000000
# 3275                                          -0.228010
# 3276                                           0.085776
# 3277                                           0.204172
#
#       sentiment_finbert_Geopolitical & Trade News  \
# 3273                                     0.283112
# 3274                                     0.018559
# 3275                                    -0.910486
# 3276                                     0.092625
# 3277                                    -0.072804
#
#       sentiment_finbert_Innovation & Future Tech  \
# 3273                                   -0.873583
# 3274                                    0.000000
# 3275                                    0.000000
# 3276                                    0.000000
# 3277                                    0.875705
#
#       sentiment_finbert_Investment & Hedge Fund Activity  ...  market_ret_1d  \
# 3273                                           0.000000   ...       0.005633
# 3274                                           0.000000   ...       0.005703
# 3275                                           0.000000   ...      -0.000268
# 3276                                           0.000000   ...      -0.004833
# 3277                                          -0.689003   ...       0.010269
#
#       market_ret_log_1d  market_ret_5d  market_ret_log_5d  market_ret_10d  \
# 3273           0.005617       0.023484           0.023213       -0.002508
# 3274           0.005686       0.008357           0.008322        0.002085
# 3275          -0.000269       0.013952           0.013856        0.005195
# 3276          -0.004845       0.005084           0.005071        0.017483
# 3277           0.010217       0.016543           0.016407        0.027526
#
#       market_ret_log_10d  market_ret_21d  market_ret_log_21d  total_news  \
# 3273           -0.002511        0.061310            0.059504        32.0
# 3274            0.002082        0.051750            0.050456        20.0
# 3275            0.005182        0.057532            0.055938        40.0
# 3276            0.017332        0.061292            0.059487        31.0
# 3277            0.027154        0.067700            0.065507        23.0
#
#       day_sentiment
# 3273      -0.102705
# 3274       0.031040
# 3275      -0.209419
# 3276       0.063467
# 3277      -0.042694
#
# [5 rows x 61 columns]
# (55, 61)

# %%
apple_df_train.columns
# Out:
# Index(['symbol_query', 'final_date_for_news',
#        'sentiment_finbert_CEO & Influencer News',
#        'sentiment_finbert_Corporate Earnings & Financials',
#        'sentiment_finbert_Corporate Strategy & Growth',
#        'sentiment_finbert_Economic Indicators & Fed Policy',
#        'sentiment_finbert_General Business & News Reporting',
#        'sentiment_finbert_Geopolitical & Trade News',
#        'sentiment_finbert_Innovation & Future Tech',
#        'sentiment_finbert_Investment & Hedge Fund Activity',
#        'sentiment_finbert_Investment Analysis & Strategy',
#        'sentiment_finbert_Layoffs & Corporate Restructuring',
#        'sentiment_finbert_Legal & Regulatory Changes',
#        'sentiment_finbert_Market Movements & Trading News',
#        'sentiment_finbert_Mergers, Acquisitions & Deals',
#        'sentiment_finbert_Product News & Updates',
#        'sentiment_finbert_Semiconductor & Chip Industry News',
#        'total_count_CEO & Influencer News',
#        'total_count_Corporate Earnings & Financials',
#        'total_count_Corporate Strategy & Growth',
#        'total_count_Economic Indicators & Fed Policy',
#        'total_count_General Business & News Reporting',
#        'total_count_Geopolitical & Trade News',
#        'total_count_Innovation & Future Tech',
#        'total_count_Investment & Hedge Fund Activity',
#        'total_count_Investment Analysis & Strategy',
#        'total_count_Layoffs & Corporate Restructuring',
#        'total_count_Legal & Regulatory Changes',
#        'total_count_Market Movements & Trading News',
#        'total_count_Mergers, Acquisitions & Deals',
#        'total_count_Product News & Updates',
#        'total_count_Semiconductor & Chip Industry News', 'date',
#        'day_start_value', 'day_max_value', 'day_min_value', 'day_end_value',
#        'day_end_raw_close', 'ret_1d', 'ret_log_1d', 'ret_5d', 'ret_log_5d',
#        'ret_10d', 'ret_log_10d', 'ret_21d', 'ret_log_21d',
#        'market_day_start_value', 'market_day_max_value',
#        'market_day_min_value', 'market_day_end_value',
#        'market_day_end_raw_close', 'market_ret_1d', 'market_ret_log_1d',
#        'market_ret_5d', 'market_ret_log_5d', 'market_ret_10d',
#        'market_ret_log_10d', 'market_ret_21d', 'market_ret_log_21d',
#        'total_news', 'day_sentiment'],
#       dtype='object')

# %% [markdown]
# # Task
# Create a panel regression model to predict `target_day_end_raw_close_next_day` using financial sentiment and market data. This involves preparing the data by creating the target variable, setting a MultiIndex with 'symbol_query' and 'final_date_for_news', and dropping NaNs. Then, split the data into training and testing sets with a split date of '2025-06-01'. Build and train a `PanelOLS` model with fixed effects for 'symbol_query' and 'final_date_for_news'. Finally, evaluate the model's performance using R-squared, MAE, and RMSE, visualize predictions, and summarize the findings.

# %% [markdown]
# ## Prepare Data for Panel Regression
#
# ### Subtask:
# Create the target variable `target_day_end_raw_close_next_day`, set a MultiIndex, and drop NaN values to prepare the data for panel regression.

# %% [markdown]
# **Reasoning**:
# To prepare the data for panel regression, I will first create the target variable `target_day_end_raw_close_next_day` by shifting the `day_end_raw_close` column by one day forward (shift(-1)) for each `symbol_query`.

# %%
avg_sentiment_df['target_day_end_raw_close_next_day'] = avg_sentiment_df.groupby('symbol_query')['day_end_raw_close'].shift(-1)
avg_sentiment_df.head()
# Out:
#   symbol_query final_date_for_news  sentiment_finbert_CEO & Influencer News  \
# 0      AAPL.US          2023-01-03                                 0.102018
# 1      AAPL.US          2023-01-04                                 0.295232
# 2      AAPL.US          2023-01-05                                -0.003781
# 3      AAPL.US          2023-01-06                                 0.339910
# 4      AAPL.US          2023-01-09                                 0.402631
#
#    sentiment_finbert_Corporate Earnings & Financials  \
# 0                                           0.006831
# 1                                           0.004108
# 2                                          -0.020834
# 3                                           0.006405
# 4                                           0.000000
#
#    sentiment_finbert_Corporate Strategy & Growth  \
# 0                                       0.011222
# 1                                       0.105869
# 2                                       0.032395
# 3                                      -0.081714
# 4                                       0.592804
#
#    sentiment_finbert_Economic Indicators & Fed Policy  \
# 0                                           0.005128
# 1                                          -0.028463
# 2                                           0.011563
# 3                                          -0.328843
# 4                                          -0.002143
#
#    sentiment_finbert_General Business & News Reporting  \
# 0                                           0.000000
# 1                                           0.187918
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.000000
#
#    sentiment_finbert_Geopolitical & Trade News  \
# 0                                     0.228387
# 1                                    -0.254930
# 2                                     0.050943
# 3                                    -0.174730
# 4                                     0.123715
#
#    sentiment_finbert_Innovation & Future Tech  \
# 0                                    0.221808
# 1                                    0.246283
# 2                                   -0.000648
# 3                                    0.095464
# 4                                    0.017661
#
#    sentiment_finbert_Investment & Hedge Fund Activity  ...  market_ret_log_1d  \
# 0                                           0.380450   ...          -0.004219
# 1                                           0.000000   ...           0.007691
# 2                                          -0.484566   ...          -0.011479
# 3                                          -0.058425   ...           0.022673
# 4                                           0.000000   ...          -0.000567
#
#    market_ret_5d  market_ret_log_5d  market_ret_10d  market_ret_log_10d  \
# 0      -0.005458          -0.005473       -0.006392           -0.006413
# 1       0.006188           0.006169        0.009842            0.009794
# 2       0.007221           0.007195       -0.003048           -0.003053
# 3       0.012101           0.012028        0.004790            0.004778
# 4       0.014199           0.014099        0.018754            0.018580
#
#    market_ret_21d  market_ret_log_21d  total_news  day_sentiment  \
# 0       -0.065197           -0.067420        29.0       0.129412
# 1       -0.056892           -0.058575        51.0       0.087933
# 2       -0.050577           -0.051901        26.0      -0.021794
# 3       -0.014600           -0.014708        23.0       0.064575
# 4       -0.013481           -0.013572        30.0       0.105967
#
#    target_day_end_raw_close_next_day
# 0                         125.080002
# 1                         124.760002
# 2                         124.889999
# 3                         129.889999
# 4                         128.119995
#
# [5 rows x 62 columns]

# %% [markdown]
# **Reasoning**:
# To prepare the data for panel regression, I will now set a MultiIndex for the `avg_sentiment_df` DataFrame using 'symbol_query' as the entity index and 'final_date_for_news' as the time index.

# %%
# avg_sentiment_df = avg_sentiment_df.set_index(['symbol_query', 'final_date_for_news'])
# avg_sentiment_df.head()

# %% [markdown]
# **Reasoning**:
# To ensure the dataset is clean and ready for panel regression, I will drop all rows containing any NaN values from the `avg_sentiment_df` DataFrame. This step is crucial for model training, as panel regression models typically require complete data.

# %%
avg_sentiment_df = avg_sentiment_df.dropna()
avg_sentiment_df.head()
# Out:
#   symbol_query final_date_for_news  sentiment_finbert_CEO & Influencer News  \
# 0      AAPL.US          2023-01-03                                 0.102018
# 1      AAPL.US          2023-01-04                                 0.295232
# 2      AAPL.US          2023-01-05                                -0.003781
# 3      AAPL.US          2023-01-06                                 0.339910
# 4      AAPL.US          2023-01-09                                 0.402631
#
#    sentiment_finbert_Corporate Earnings & Financials  \
# 0                                           0.006831
# 1                                           0.004108
# 2                                          -0.020834
# 3                                           0.006405
# 4                                           0.000000
#
#    sentiment_finbert_Corporate Strategy & Growth  \
# 0                                       0.011222
# 1                                       0.105869
# 2                                       0.032395
# 3                                      -0.081714
# 4                                       0.592804
#
#    sentiment_finbert_Economic Indicators & Fed Policy  \
# 0                                           0.005128
# 1                                          -0.028463
# 2                                           0.011563
# 3                                          -0.328843
# 4                                          -0.002143
#
#    sentiment_finbert_General Business & News Reporting  \
# 0                                           0.000000
# 1                                           0.187918
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.000000
#
#    sentiment_finbert_Geopolitical & Trade News  \
# 0                                     0.228387
# 1                                    -0.254930
# 2                                     0.050943
# 3                                    -0.174730
# 4                                     0.123715
#
#    sentiment_finbert_Innovation & Future Tech  \
# 0                                    0.221808
# 1                                    0.246283
# 2                                   -0.000648
# 3                                    0.095464
# 4                                    0.017661
#
#    sentiment_finbert_Investment & Hedge Fund Activity  ...  market_ret_log_1d  \
# 0                                           0.380450   ...          -0.004219
# 1                                           0.000000   ...           0.007691
# 2                                          -0.484566   ...          -0.011479
# 3                                          -0.058425   ...           0.022673
# 4                                           0.000000   ...          -0.000567
#
#    market_ret_5d  market_ret_log_5d  market_ret_10d  market_ret_log_10d  \
# 0      -0.005458          -0.005473       -0.006392           -0.006413
# 1       0.006188           0.006169        0.009842            0.009794
# 2       0.007221           0.007195       -0.003048           -0.003053
# 3       0.012101           0.012028        0.004790            0.004778
# 4       0.014199           0.014099        0.018754            0.018580
#
#    market_ret_21d  market_ret_log_21d  total_news  day_sentiment  \
# 0       -0.065197           -0.067420        29.0       0.129412
# 1       -0.056892           -0.058575        51.0       0.087933
# 2       -0.050577           -0.051901        26.0      -0.021794
# 3       -0.014600           -0.014708        23.0       0.064575
# 4       -0.013481           -0.013572        30.0       0.105967
#
#    target_day_end_raw_close_next_day
# 0                         125.080002
# 1                         124.760002
# 2                         124.889999
# 3                         129.889999
# 4                         128.119995
#
# [5 rows x 62 columns]

# %% [markdown]
# ## Define Features and Target
#
# ### Subtask:
# Specify the independent variables (features) and the dependent variable (`target_day_end_raw_close_next_day`). Split the prepared data into training and testing sets based on the original date split ('2025-06-01').

# %% [markdown]
# **Reasoning**:
# To prepare the data for modeling, I will first define the list of feature columns and the target variable as specified in the instructions. This involves selecting all sentiment-related columns, total news count, daily sentiment, and market return columns.

# %%
sentiment_columns = [col for col in avg_sentiment_df.columns if 'sentiment_finbert_' in col]

total_count_columns = [col for col in avg_sentiment_df.columns if 'total_count_' in col]

features = sentiment_columns + total_count_columns + [
    'total_news',
    'day_sentiment',
    'ret_1d',
    'market_ret_1d',
    'ret_5d',
    'market_ret_5d',
    'ret_10d',
    'market_ret_10d',
    'ret_21d',
    'market_ret_21d'
]

target = 'target_day_end_raw_close_next_day'

print("Features defined.")
print(features)
print("Target defined.")
# Out:
# Features defined.
# ['sentiment_finbert_CEO & Influencer News', 'sentiment_finbert_Corporate Earnings & Financials', 'sentiment_finbert_Corporate Strategy & Growth', 'sentiment_finbert_Economic Indicators & Fed Policy', 'sentiment_finbert_General Business & News Reporting', 'sentiment_finbert_Geopolitical & Trade News', 'sentiment_finbert_Innovation & Future Tech', 'sentiment_finbert_Investment & Hedge Fund Activity', 'sentiment_finbert_Investment Analysis & Strategy', 'sentiment_finbert_Layoffs & Corporate Restructuring', 'sentiment_finbert_Legal & Regulatory Changes', 'sentiment_finbert_Market Movements & Trading News', 'sentiment_finbert_Mergers, Acquisitions & Deals', 'sentiment_finbert_Product News & Updates', 'sentiment_finbert_Semiconductor & Chip Industry News', 'total_count_CEO & Influencer News', 'total_count_Corporate Earnings & Financials', 'total_count_Corporate Strategy & Growth', 'total_count_Economic Indicators & Fed Policy', 'total_count_General Business & News Reporting', 'total_count_Geopolitical & Trade News', 'total_count_Innovation & Future Tech', 'total_count_Investment & Hedge Fund Activity', 'total_count_Investment Analysis & Strategy', 'total_count_Layoffs & Corporate Restructuring', 'total_count_Legal & Regulatory Changes', 'total_count_Market Movements & Trading News', 'total_count_Mergers, Acquisitions & Deals', 'total_count_Product News & Updates', 'total_count_Semiconductor & Chip Industry News', 'total_news', 'day_sentiment', 'ret_1d', 'market_ret_1d', 'ret_5d', 'market_ret_5d', 'ret_10d', 'market_ret_10d', 'ret_21d', 'market_ret_21d']
# Target defined.

# %% [markdown]
# **Reasoning**:
# To create the training and testing datasets, I will filter the `avg_sentiment_df` based on the specified date split ('2025-06-01') for both features and the target variable.

# %%
apple_df = avg_sentiment_df.loc[avg_sentiment_df['symbol_query'] == 'MSFT.US',:].copy()

apple_df = apple_df.set_index(['final_date_for_news'])

apple_df_train = apple_df.loc[apple_df['date'] < '2025-06-01',:].copy()

apple_df_test = apple_df.loc[apple_df['date'] >= '2025-06-01', :].copy()

display(apple_df_train.head())
display(apple_df_train.shape)
display(apple_df_test.head())
display(apple_df_test.shape)

apple_df_x_train = apple_df_train[features]
apple_df_y_train = apple_df_train[target]

apple_df_x_test = apple_df_test[features]
apple_df_y_test = apple_df_test[target]

display(apple_df_x_train.head())
display(apple_df_x_test.head())
display(apple_df_y_train.head())
display(apple_df_y_test.head())

# X_train = apple_df.loc[(slice(None), slice(None, '2025-05-31')), features]
# y_train = apple_df.loc[(slice(None), slice(None, '2025-05-31')), target]

# X_test = apple_df.loc[(slice(None), slice('2025-06-01', None)), features]
# y_test = apple_df.loc[(slice(None), slice('2025-06-01', None)), target]

# print(f"X_train shape: {X_train.shape}")
# print(f"y_train shape: {y_train.shape}")
# print(f"X_test shape: {X_test.shape}")
# print(f"y_test shape: {y_test.shape}")
# Out:
#                     symbol_query  sentiment_finbert_CEO & Influencer News  \
# final_date_for_news
# 2023-01-03               MSFT.US                                 0.111051
# 2023-01-04               MSFT.US                                 0.478465
# 2023-01-05               MSFT.US                                 0.205051
# 2023-01-06               MSFT.US                                 0.517990
# 2023-01-09               MSFT.US                                 0.270507
#
#                      sentiment_finbert_Corporate Earnings & Financials  \
# final_date_for_news
# 2023-01-03                                                    0.000000
# 2023-01-04                                                   -0.047136
# 2023-01-05                                                    0.000000
# 2023-01-06                                                    0.000000
# 2023-01-09                                                    0.000000
#
#                      sentiment_finbert_Corporate Strategy & Growth  \
# final_date_for_news
# 2023-01-03                                                0.000000
# 2023-01-04                                                0.524175
# 2023-01-05                                                0.321901
# 2023-01-06                                                0.000000
# 2023-01-09                                               -0.399397
#
#                      sentiment_finbert_Economic Indicators & Fed Policy  \
# final_date_for_news
# 2023-01-03                                                    0.000000
# 2023-01-04                                                   -0.031575
# 2023-01-05                                                   -0.028175
# 2023-01-06                                                    0.003330
# 2023-01-09                                                    0.000000
#
#                      sentiment_finbert_General Business & News Reporting  \
# final_date_for_news
# 2023-01-03                                                    0.000000
# 2023-01-04                                                    0.000000
# 2023-01-05                                                    0.088447
# 2023-01-06                                                    0.000000
# 2023-01-09                                                    0.000000
#
#                      sentiment_finbert_Geopolitical & Trade News  \
# final_date_for_news
# 2023-01-03                                             -0.783932
# 2023-01-04                                              0.568508
# 2023-01-05                                              0.098990
# 2023-01-06                                             -0.895080
# 2023-01-09                                             -0.045231
#
#                      sentiment_finbert_Innovation & Future Tech  \
# final_date_for_news
# 2023-01-03                                             0.007867
# 2023-01-04                                             0.575411
# 2023-01-05                                            -0.525969
# 2023-01-06                                             0.755901
# 2023-01-09                                            -0.028778
#
#                      sentiment_finbert_Investment & Hedge Fund Activity  \
# final_date_for_news
# 2023-01-03                                                    0.000000
# 2023-01-04                                                    0.268354
# 2023-01-05                                                    0.423550
# 2023-01-06                                                    0.112854
# 2023-01-09                                                    0.000000
#
#                      sentiment_finbert_Investment Analysis & Strategy  ...  \
# final_date_for_news                                                    ...
# 2023-01-03                                                        0.0  ...
# 2023-01-04                                                        0.0  ...
# 2023-01-05                                                        0.0  ...
# 2023-01-06                                                        0.0  ...
# 2023-01-09                                                        0.0  ...
#
#                      market_ret_log_1d  market_ret_5d  market_ret_log_5d  \
# final_date_for_news
# 2023-01-03                   -0.004219      -0.005458          -0.005473
# 2023-01-04                    0.007691       0.006188           0.006169
# 2023-01-05                   -0.011479       0.007221           0.007195
# 2023-01-06                    0.022673       0.012101           0.012028
# 2023-01-09                   -0.000567       0.014199           0.014099
#
#                      market_ret_10d  market_ret_log_10d  market_ret_21d  \
# final_date_for_news
# 2023-01-03                -0.006392           -0.006413       -0.065197
# 2023-01-04                 0.009842            0.009794       -0.056892
# 2023-01-05                -0.003048           -0.003053       -0.050577
# 2023-01-06                 0.004790            0.004778       -0.014600
# 2023-01-09                 0.018754            0.018580       -0.013481
#
#                      market_ret_log_21d  total_news  day_sentiment  \
# final_date_for_news
# 2023-01-03                    -0.067420        10.0      -0.016513
# 2023-01-04                    -0.058575        28.0       0.219938
# 2023-01-05                    -0.051901        36.0       0.217139
# 2023-01-06                    -0.014708        15.0       0.164615
# 2023-01-09                    -0.013572        10.0       0.061689
#
#                      target_day_end_raw_close_next_day
# final_date_for_news
# 2023-01-03                                  225.960007
# 2023-01-04                                  221.759995
# 2023-01-05                                  219.350006
# 2023-01-06                                  226.410004
# 2023-01-09                                  227.330002
#
# [5 rows x 61 columns]
# (595, 61)
#                     symbol_query  sentiment_finbert_CEO & Influencer News  \
# final_date_for_news
# 2025-06-02               MSFT.US                                 0.363579
# 2025-06-03               MSFT.US                                 0.857679
# 2025-06-04               MSFT.US                                -0.681036
# 2025-06-05               MSFT.US                                 0.325587
# 2025-06-06               MSFT.US                                 0.625829
#
#                      sentiment_finbert_Corporate Earnings & Financials  \
# final_date_for_news
# 2025-06-02                                                    0.000000
# 2025-06-03                                                   -0.427940
# 2025-06-04                                                   -0.507475
# 2025-06-05                                                   -0.913353
# 2025-06-06                                                   -0.298326
#
#                      sentiment_finbert_Corporate Strategy & Growth  \
# final_date_for_news
# 2025-06-02                                               -0.018180
# 2025-06-03                                                0.000000
# 2025-06-04                                                0.000000
# 2025-06-05                                                0.463495
# 2025-06-06                                               -0.896047
#
#                      sentiment_finbert_Economic Indicators & Fed Policy  \
# final_date_for_news
# 2025-06-02                                                         0.0
# 2025-06-03                                                         0.0
# 2025-06-04                                                         0.0
# 2025-06-05                                                         0.0
# 2025-06-06                                                         0.0
#
#                      sentiment_finbert_General Business & News Reporting  \
# final_date_for_news
# 2025-06-02                                                    0.000000
# 2025-06-03                                                    0.000000
# 2025-06-04                                                   -0.228010
# 2025-06-05                                                    0.085776
# 2025-06-06                                                    0.204172
#
#                      sentiment_finbert_Geopolitical & Trade News  \
# final_date_for_news
# 2025-06-02                                              0.283112
# 2025-06-03                                              0.018559
# 2025-06-04                                             -0.910486
# 2025-06-05                                              0.092625
# 2025-06-06                                             -0.072804
#
#                      sentiment_finbert_Innovation & Future Tech  \
# final_date_for_news
# 2025-06-02                                            -0.873583
# 2025-06-03                                             0.000000
# 2025-06-04                                             0.000000
# 2025-06-05                                             0.000000
# 2025-06-06                                             0.875705
#
#                      sentiment_finbert_Investment & Hedge Fund Activity  \
# final_date_for_news
# 2025-06-02                                                    0.000000
# 2025-06-03                                                    0.000000
# 2025-06-04                                                    0.000000
# 2025-06-05                                                    0.000000
# 2025-06-06                                                   -0.689003
#
#                      sentiment_finbert_Investment Analysis & Strategy  ...  \
# final_date_for_news                                                    ...
# 2025-06-02                                                  -0.432191  ...
# 2025-06-03                                                  -0.456106  ...
# 2025-06-04                                                  -0.317569  ...
# 2025-06-05                                                  -0.061886  ...
# 2025-06-06                                                  -0.056865  ...
#
#                      market_ret_log_1d  market_ret_5d  market_ret_log_5d  \
# final_date_for_news
# 2025-06-02                    0.005617       0.023484           0.023213
# 2025-06-03                    0.005686       0.008357           0.008322
# 2025-06-04                   -0.000269       0.013952           0.013856
# 2025-06-05                   -0.004845       0.005084           0.005071
# 2025-06-06                    0.010217       0.016543           0.016407
#
#                      market_ret_10d  market_ret_log_10d  market_ret_21d  \
# final_date_for_news
# 2025-06-02                -0.002508           -0.002511        0.061310
# 2025-06-03                 0.002085            0.002082        0.051750
# 2025-06-04                 0.005195            0.005182        0.057532
# 2025-06-05                 0.017483            0.017332        0.061292
# 2025-06-06                 0.027526            0.027154        0.067700
#
#                      market_ret_log_21d  total_news  day_sentiment  \
# final_date_for_news
# 2025-06-02                     0.059504        32.0      -0.102705
# 2025-06-03                     0.050456        20.0       0.031040
# 2025-06-04                     0.055938        40.0      -0.209419
# 2025-06-05                     0.059487        31.0       0.063467
# 2025-06-06                     0.065507        23.0      -0.042694
#
#                      target_day_end_raw_close_next_day
# final_date_for_news
# 2025-06-02                                  460.859985
# 2025-06-03                                  463.019989
# 2025-06-04                                  464.029999
# 2025-06-05                                  468.779999
# 2025-06-06                                  468.619995
#
# [5 rows x 61 columns]
# (54, 61)
#                      sentiment_finbert_CEO & Influencer News  \
# final_date_for_news
# 2023-01-03                                          0.111051
# 2023-01-04                                          0.478465
# 2023-01-05                                          0.205051
# 2023-01-06                                          0.517990
# 2023-01-09                                          0.270507
#
#                      sentiment_finbert_Corporate Earnings & Financials  \
# final_date_for_news
# 2023-01-03                                                    0.000000
# 2023-01-04                                                   -0.047136
# 2023-01-05                                                    0.000000
# 2023-01-06                                                    0.000000
# 2023-01-09                                                    0.000000
#
#                      sentiment_finbert_Corporate Strategy & Growth  \
# final_date_for_news
# 2023-01-03                                                0.000000
# 2023-01-04                                                0.524175
# 2023-01-05                                                0.321901
# 2023-01-06                                                0.000000
# 2023-01-09                                               -0.399397
#
#                      sentiment_finbert_Economic Indicators & Fed Policy  \
# final_date_for_news
# 2023-01-03                                                    0.000000
# 2023-01-04                                                   -0.031575
# 2023-01-05                                                   -0.028175
# 2023-01-06                                                    0.003330
# 2023-01-09                                                    0.000000
#
#                      sentiment_finbert_General Business & News Reporting  \
# final_date_for_news
# 2023-01-03                                                    0.000000
# 2023-01-04                                                    0.000000
# 2023-01-05                                                    0.088447
# 2023-01-06                                                    0.000000
# 2023-01-09                                                    0.000000
#
#                      sentiment_finbert_Geopolitical & Trade News  \
# final_date_for_news
# 2023-01-03                                             -0.783932
# 2023-01-04                                              0.568508
# 2023-01-05                                              0.098990
# 2023-01-06                                             -0.895080
# 2023-01-09                                             -0.045231
#
#                      sentiment_finbert_Innovation & Future Tech  \
# final_date_for_news
# 2023-01-03                                             0.007867
# 2023-01-04                                             0.575411
# 2023-01-05                                            -0.525969
# 2023-01-06                                             0.755901
# 2023-01-09                                            -0.028778
#
#                      sentiment_finbert_Investment & Hedge Fund Activity  \
# final_date_for_news
# 2023-01-03                                                    0.000000
# 2023-01-04                                                    0.268354
# 2023-01-05                                                    0.423550
# 2023-01-06                                                    0.112854
# 2023-01-09                                                    0.000000
#
#                      sentiment_finbert_Investment Analysis & Strategy  \
# final_date_for_news
# 2023-01-03                                                        0.0
# 2023-01-04                                                        0.0
# 2023-01-05                                                        0.0
# 2023-01-06                                                        0.0
# 2023-01-09                                                        0.0
#
#                      sentiment_finbert_Layoffs & Corporate Restructuring  ...  \
# final_date_for_news                                                       ...
# 2023-01-03                                                   -0.165045    ...
# 2023-01-04                                                    0.003599    ...
# 2023-01-05                                                    0.831633    ...
# 2023-01-06                                                    0.006797    ...
# 2023-01-09                                                    0.000000    ...
#
#                      total_news  day_sentiment    ret_1d  market_ret_1d  \
# final_date_for_news
# 2023-01-03                 10.0      -0.016513  0.003127      -0.004210
# 2023-01-04                 28.0       0.219938 -0.048189       0.007720
# 2023-01-05                 36.0       0.217139 -0.018587      -0.011413
# 2023-01-06                 15.0       0.164615 -0.010868       0.022932
# 2023-01-09                 10.0       0.061689  0.032186      -0.000567
#
#                        ret_5d  market_ret_5d   ret_10d  market_ret_10d  \
# final_date_for_news
# 2023-01-03           0.014790      -0.005458 -0.025091       -0.006392
# 2023-01-04          -0.041852       0.006188 -0.053412        0.009842
# 2023-01-05          -0.052996       0.007221 -0.069877       -0.003048
# 2023-01-06          -0.069170       0.012101 -0.086460        0.004790
# 2023-01-09          -0.043311       0.014199 -0.031898        0.018754
#
#                       ret_21d  market_ret_21d
# final_date_for_news
# 2023-01-03          -0.053882       -0.065197
# 2023-01-04          -0.095038       -0.056892
# 2023-01-05          -0.106023       -0.050577
# 2023-01-06          -0.100213       -0.014600
# 2023-01-09          -0.065233       -0.013481
#
# [5 rows x 40 columns]
#                      sentiment_finbert_CEO & Influencer News  \
# final_date_for_news
# 2025-06-02                                          0.363579
# 2025-06-03                                          0.857679
# 2025-06-04                                         -0.681036
# 2025-06-05                                          0.325587
# 2025-06-06                                          0.625829
#
#                      sentiment_finbert_Corporate Earnings & Financials  \
# final_date_for_news
# 2025-06-02                                                    0.000000
# 2025-06-03                                                   -0.427940
# 2025-06-04                                                   -0.507475
# 2025-06-05                                                   -0.913353
# 2025-06-06                                                   -0.298326
#
#                      sentiment_finbert_Corporate Strategy & Growth  \
# final_date_for_news
# 2025-06-02                                               -0.018180
# 2025-06-03                                                0.000000
# 2025-06-04                                                0.000000
# 2025-06-05                                                0.463495
# 2025-06-06                                               -0.896047
#
#                      sentiment_finbert_Economic Indicators & Fed Policy  \
# final_date_for_news
# 2025-06-02                                                         0.0
# 2025-06-03                                                         0.0
# 2025-06-04                                                         0.0
# 2025-06-05                                                         0.0
# 2025-06-06                                                         0.0
#
#                      sentiment_finbert_General Business & News Reporting  \
# final_date_for_news
# 2025-06-02                                                    0.000000
# 2025-06-03                                                    0.000000
# 2025-06-04                                                   -0.228010
# 2025-06-05                                                    0.085776
# 2025-06-06                                                    0.204172
#
#                      sentiment_finbert_Geopolitical & Trade News  \
# final_date_for_news
# 2025-06-02                                              0.283112
# 2025-06-03                                              0.018559
# 2025-06-04                                             -0.910486
# 2025-06-05                                              0.092625
# 2025-06-06                                             -0.072804
#
#                      sentiment_finbert_Innovation & Future Tech  \
# final_date_for_news
# 2025-06-02                                            -0.873583
# 2025-06-03                                             0.000000
# 2025-06-04                                             0.000000
# 2025-06-05                                             0.000000
# 2025-06-06                                             0.875705
#
#                      sentiment_finbert_Investment & Hedge Fund Activity  \
# final_date_for_news
# 2025-06-02                                                    0.000000
# 2025-06-03                                                    0.000000
# 2025-06-04                                                    0.000000
# 2025-06-05                                                    0.000000
# 2025-06-06                                                   -0.689003
#
#                      sentiment_finbert_Investment Analysis & Strategy  \
# final_date_for_news
# 2025-06-02                                                  -0.432191
# 2025-06-03                                                  -0.456106
# 2025-06-04                                                  -0.317569
# 2025-06-05                                                  -0.061886
# 2025-06-06                                                  -0.056865
#
#                      sentiment_finbert_Layoffs & Corporate Restructuring  ...  \
# final_date_for_news                                                       ...
# 2025-06-02                                                    0.000000    ...
# 2025-06-03                                                    0.016998    ...
# 2025-06-04                                                    0.000000    ...
# 2025-06-05                                                    0.000000    ...
# 2025-06-06                                                    0.000000    ...
#
#                      total_news  day_sentiment    ret_1d  market_ret_1d  \
# final_date_for_news
# 2025-06-02                 32.0      -0.102705  0.002964       0.005633
# 2025-06-03                 20.0       0.031040  0.008689       0.005703
# 2025-06-04                 40.0      -0.209419  0.004687      -0.000268
# 2025-06-05                 31.0       0.063467  0.002181      -0.004833
# 2025-06-06                 23.0      -0.042694  0.010236       0.010269
#
#                        ret_5d  market_ret_5d   ret_10d  market_ret_10d  \
# final_date_for_news
# 2025-06-02           0.017776       0.023484  0.018185       -0.002508
# 2025-06-03           0.010392       0.008357  0.022316        0.002085
# 2025-06-04           0.013328       0.013952  0.019149        0.005195
# 2025-06-05           0.019152       0.005084  0.027047        0.017483
# 2025-06-06           0.029064       0.016543  0.032783        0.027526
#
#                       ret_21d  market_ret_21d
# final_date_for_news
# 2025-06-02           0.075288        0.061310
# 2025-06-03           0.071792        0.051750
# 2025-06-04           0.071533        0.057532
# 2025-06-05           0.076211        0.061292
# 2025-06-06           0.087379        0.067700
#
# [5 rows x 40 columns]
# final_date_for_news
# 2023-01-03    225.960007
# 2023-01-04    221.759995
# 2023-01-05    219.350006
# 2023-01-06    226.410004
# 2023-01-09    227.330002
# Name: target_day_end_raw_close_next_day, dtype: float64
# final_date_for_news
# 2025-06-02    460.859985
# 2025-06-03    463.019989
# 2025-06-04    464.029999
# 2025-06-05    468.779999
# 2025-06-06    468.619995
# Name: target_day_end_raw_close_next_day, dtype: float64

# %% [markdown]
# ## Build and Train Panel Regression Model
#
# ### Subtask:
# Utilize the `PanelOLS` function from the `linearmodels` library to build a regression model. The model will include fixed effects for 'symbol_query' (company) and 'final_date_for_news' (news date), as requested, to account for unobserved heterogeneity across entities and time periods. Train the model using the training data.

# %% [markdown]
# **Reasoning**:
# To build and train the panel regression model, I will import the `PanelOLS` class, instantiate it with the specified dependent and independent variables and fixed effects, then fit the model to the training data and display its summary.

# %%
import statsmodels.api as sm

apple_df_x_train = sm.add_constant(apple_df_x_train)
model_apple = sm.OLS(apple_df_y_train, apple_df_x_train)

results = model_apple.fit()

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     target_day_end_raw_close_next_day   R-squared:                       0.736
# Model:                                           OLS   Adj. R-squared:                  0.718
# Method:                                Least Squares   F-statistic:                     39.72
# Date:                               Tue, 18 Nov 2025   Prob (F-statistic):          9.39e-135
# Time:                                       01:09:28   Log-Likelihood:                -2876.8
# No. Observations:                                595   AIC:                             5834.
# Df Residuals:                                    555   BIC:                             6009.
# Df Model:                                         39
# Covariance Type:                           nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                  316.7303      4.841     65.428      0.000     307.222     326.239
# sentiment_finbert_CEO & Influencer News                 -3.2034      4.274     -0.749      0.454     -11.599       5.192
# sentiment_finbert_Corporate Earnings & Financials       -6.5723      4.066     -1.617      0.107     -14.558       1.414
# sentiment_finbert_Corporate Strategy & Growth           -8.6667      3.748     -2.312      0.021     -16.028      -1.305
# sentiment_finbert_Economic Indicators & Fed Policy      -5.6567      7.726     -0.732      0.464     -20.833       9.520
# sentiment_finbert_General Business & News Reporting      3.2721      3.951      0.828      0.408      -4.489      11.033
# sentiment_finbert_Geopolitical & Trade News             -8.6978      4.238     -2.052      0.041     -17.022      -0.373
# sentiment_finbert_Innovation & Future Tech             -14.0400      4.149     -3.384      0.001     -22.189      -5.891
# sentiment_finbert_Investment & Hedge Fund Activity      -4.6382      3.905     -1.188      0.235     -12.309       3.032
# sentiment_finbert_Investment Analysis & Strategy        -1.7152      4.848     -0.354      0.724     -11.239       7.808
# sentiment_finbert_Layoffs & Corporate Restructuring    -14.6313      6.421     -2.279      0.023     -27.243      -2.019
# sentiment_finbert_Legal & Regulatory Changes             8.0110      7.268      1.102      0.271      -6.264      22.286
# sentiment_finbert_Market Movements & Trading News        4.2563      4.335      0.982      0.327      -4.260      12.772
# sentiment_finbert_Mergers, Acquisitions & Deals         -1.8405      6.111     -0.301      0.763     -13.844      10.163
# sentiment_finbert_Product News & Updates                -5.2001      4.611     -1.128      0.260     -14.257       3.857
# sentiment_finbert_Semiconductor & Chip Industry News    -5.9178      5.147     -1.150      0.251     -16.027       4.191
# total_count_CEO & Influencer News                       68.8622     10.781      6.387      0.000      47.685      90.039
# total_count_Corporate Earnings & Financials             28.1704     25.714      1.096      0.274     -22.338      78.679
# total_count_Corporate Strategy & Growth                 57.1801     19.933      2.869      0.004      18.027      96.333
# total_count_Economic Indicators & Fed Policy          -151.2125     41.204     -3.670      0.000    -232.148     -70.277
# total_count_General Business & News Reporting          107.4237     16.533      6.497      0.000      74.949     139.899
# total_count_Geopolitical & Trade News                   49.0846     16.079      3.053      0.002      17.501      80.668
# total_count_Innovation & Future Tech                    34.7615     12.418      2.799      0.005      10.369      59.154
# total_count_Investment & Hedge Fund Activity             6.6364     20.190      0.329      0.743     -33.022      46.295
# total_count_Investment Analysis & Strategy             143.7245      9.259     15.522      0.000     125.537     161.912
# total_count_Layoffs & Corporate Restructuring         -360.4813     36.631     -9.841      0.000    -432.433    -288.530
# total_count_Legal & Regulatory Changes                  82.6306     21.648      3.817      0.000      40.109     125.152
# total_count_Market Movements & Trading News             25.2956     13.944      1.814      0.070      -2.093      52.684
# total_count_Mergers, Acquisitions & Deals              136.9429     17.071      8.022      0.000     103.411     170.474
# total_count_Product News & Updates                     -54.2262     15.507     -3.497      0.001     -84.687     -23.766
# total_count_Semiconductor & Chip Industry News         141.9380     13.035     10.889      0.000     116.334     167.542
# total_news                                              -0.2851      0.121     -2.363      0.018      -0.522      -0.048
# day_sentiment                                           11.8961     13.530      0.879      0.380     -14.681      38.473
# ret_1d                                                  20.8573    112.988      0.185      0.854    -201.078     242.793
# market_ret_1d                                            6.5511    156.591      0.042      0.967    -301.032     314.134
# ret_5d                                                 113.3052     77.485      1.462      0.144     -38.895     265.505
# market_ret_5d                                          -85.8369    110.922     -0.774      0.439    -303.716     132.042
# ret_10d                                                 56.2852     61.921      0.909      0.364     -65.343     177.913
# market_ret_10d                                          67.8777     93.874      0.723      0.470    -116.515     252.270
# ret_21d                                                -76.6735     35.645     -2.151      0.032    -146.689      -6.658
# market_ret_21d                                         378.3326     59.251      6.385      0.000     261.948     494.717
# ==============================================================================
# Omnibus:                       16.952   Durbin-Watson:                   1.076
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.377
# Skew:                          -0.319   Prob(JB):                     3.76e-05
# Kurtosis:                       3.644   Cond. No.                     4.08e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.34e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Add a constant to the test features, as was done for training
apple_df_x_test_const = sm.add_constant(apple_df_x_test)

# Generate predictions on the test set using the OLS model results
predictions = results.predict(apple_df_x_test_const)

# Calculate residuals
residuals = apple_df_y_test - predictions

# Create a scatter plot of predicted values vs. residuals
plt.figure(figsize=(10, 6))
plt.scatter(predictions, residuals, alpha=0.5)
plt.axhline(y=0, color='r', linestyle='--') # Add a horizontal line at 0 for reference
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs. Predicted Values (OLS Model)')
plt.grid(True)
plt.show()

print(f"Mean of residuals: {residuals.mean():.4f}")
print(f"Standard deviation of residuals: {residuals.std():.4f}")
# Out:
# Mean of residuals: 91.8289
# Standard deviation of residuals: 39.0806

# %%
def get_mlr_equation_string(results):
    params = results.params
    intercept = params.get("const", 0.0)

    terms = []
    for name, val in params.items():
        if name == "const":
            continue
        terms.append(f"{val:.4f} * {name}")

    if terms:
        eq = "y = " + f"{intercept:.4f} + " + " + ".join(terms)
    else:
        eq = "y = " + f"{intercept:.4f}"
    return eq

mlr_equation_str = get_mlr_equation_string(results)
print(mlr_equation_str)
# Out:
# y = 316.7303 + -3.2034 * sentiment_finbert_CEO & Influencer News + -6.5723 * sentiment_finbert_Corporate Earnings & Financials + -8.6667 * sentiment_finbert_Corporate Strategy & Growth + -5.6567 * sentiment_finbert_Economic Indicators & Fed Policy + 3.2721 * sentiment_finbert_General Business & News Reporting + -8.6978 * sentiment_finbert_Geopolitical & Trade News + -14.0400 * sentiment_finbert_Innovation & Future Tech + -4.6382 * sentiment_finbert_Investment & Hedge Fund Activity + -1.7152 * sentiment_finbert_Investment Analysis & Strategy + -14.6313 * sentiment_finbert_Layoffs & Corporate Restructuring + 8.0110 * sentiment_finbert_Legal & Regulatory Changes + 4.2563 * sentiment_finbert_Market Movements & Trading News + -1.8405 * sentiment_finbert_Mergers, Acquisitions & Deals + -5.2001 * sentiment_finbert_Product News & Updates + -5.9178 * sentiment_finbert_Semiconductor & Chip Industry News + 68.8622 * total_count_CEO & Influencer News + 28.1704 * total_count_Corporate Earnings & Financials + 57.1801 * total_count_Corporate Strategy & Growth + -151.2125 * total_count_Economic Indicators & Fed Policy + 107.4237 * total_count_General Business & News Reporting + 49.0846 * total_count_Geopolitical & Trade News + 34.7615 * total_count_Innovation & Future Tech + 6.6364 * total_count_Investment & Hedge Fund Activity + 143.7245 * total_count_Investment Analysis & Strategy + -360.4813 * total_count_Layoffs & Corporate Restructuring + 82.6306 * total_count_Legal & Regulatory Changes + 25.2956 * total_count_Market Movements & Trading News + 136.9429 * total_count_Mergers, Acquisitions & Deals + -54.2262 * total_count_Product News & Updates + 141.9380 * total_count_Semiconductor & Chip Industry News + -0.2851 * total_news + 11.8961 * day_sentiment + 20.8573 * ret_1d + 6.5511 * market_ret_1d + 113.3052 * ret_5d + -85.8369 * market_ret_5d + 56.2852 * ret_10d + 67.8777 * market_ret_10d + -76.6735 * ret_21d + 378.3326 * market_ret_21d

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

def plot_feature_vs_target_with_original_mlr_line(X, y, results, feature_name, symbol, equation_str):
    """
    For a given feature:
      - Scatter: feature vs actual target (y)
      - Line: predictions from the ORIGINAL multivariate regression,
              varying this feature, holding all other features at their mean.
      - The SAME multivariate equation string is shown on every plot.
    """
    if feature_name not in X.columns:
        print(f"[{symbol}] Feature {feature_name} not in X.")
        return

    # 1) Subset for scatter (actual data)
    sub = X[[feature_name]].copy()
    sub["y_true"] = y
    sub = sub.dropna()

    if sub[feature_name].nunique() < 2:
        print(f"[{symbol} | {feature_name}] Feature nearly constant; skipping.")
        return

    x = sub[feature_name].values
    y_true = sub["y_true"].values

    # 2) Build line using ORIGINAL multivariate model (no refit!)
    params = results.params
    exog_names = results.model.exog_names  # e.g. ['const', 'feat1', 'feat2', ...]

    # Model feature names (exclude const)
    model_features = [name for name in exog_names if name != "const"]

    # keep only model features that exist in X
    model_features_in_X = [f for f in model_features if f in X.columns]

    # Base means from the sample we're plotting on
    X_sample = X.loc[sub.index, model_features_in_X].copy()
    base_means = X_sample.mean()

    # Grid over this feature
    x_grid = np.linspace(x.min(), x.max(), 100)

    rows = []
    for val in x_grid:
        row = base_means.copy()
        row[feature_name] = val
        rows.append(row)

    # DataFrame of features (only those we have)
    X_grid = pd.DataFrame(rows, columns=model_features_in_X)

    # Add any model features that aren't in X_grid as zeros (or some default)
    for feat in model_features:
        if feat not in X_grid.columns:
            X_grid[feat] = 0.0  # default; you can change to a global mean if you want

    # Ensure column order matches model's expectation (excluding const for now)
    X_grid = X_grid[[f for f in exog_names if f != "const"]]

    # Add constant and align exactly with exog_names
    X_grid_const = sm.add_constant(X_grid, has_constant="add")

    # Make sure all exog_names exist; if not, add zero columns
    for name in exog_names:
        if name not in X_grid_const.columns:
            X_grid_const[name] = 0.0

    # Final column order: exactly exog_names
    X_grid_const = X_grid_const[exog_names]

    # Predict using ORIGINAL multivariate model
    y_line = results.predict(X_grid_const)

    # 3) Plot
    plt.figure(figsize=(8, 5))
    plt.scatter(x, y_true, alpha=0.5, label="Actual target")
    plt.plot(x_grid, y_line, linestyle="--", label="Original MLR line")

    plt.xlabel(feature_name)
    plt.ylabel(y.name or "target")
    plt.title(f"{symbol}: {y.name or 'target'} vs {feature_name}")

    # EXACT SAME equation string on all plots
    '''
    plt.figtext(
        0.5, -0.05,
        equation_str,
        wrap=True,
        horizontalalignment="center",
        fontsize=9
    )
    '''

    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
X_test_no_const = apple_df_x_test.copy()
y_test = apple_df_y_test

for feature in features:
    if feature not in X_test_no_const.columns:
        continue

    print(f"Plotting {feature} vs target for MSFT.US with original MLR line")
    plot_feature_vs_target_with_original_mlr_line(
        X=X_test_no_const,
        y=y_test,
        results=results,
        feature_name=feature,
        symbol="MSFT.US",
        equation_str=mlr_equation_str
    )
# Out:
# Plotting sentiment_finbert_CEO & Influencer News vs target for MSFT.US with original MLR line
# Plotting sentiment_finbert_Corporate Earnings & Financials vs target for MSFT.US with original MLR line
# Plotting sentiment_finbert_Corporate Strategy & Growth vs target for MSFT.US with original MLR line
# Plotting sentiment_finbert_Economic Indicators & Fed Policy vs target for MSFT.US with original MLR line
# [MSFT.US | sentiment_finbert_Economic Indicators & Fed Policy] Feature nearly constant; skipping.
# Plotting sentiment_finbert_General Business & News Reporting vs target for MSFT.US with original MLR line
# Plotting sentiment_finbert_Geopolitical & Trade News vs target for MSFT.US with original MLR line
# Plotting sentiment_finbert_Innovation & Future Tech vs target for MSFT.US with original MLR line
# Plotting sentiment_finbert_Investment & Hedge Fund Activity vs target for MSFT.US with original MLR line
# Plotting sentiment_finbert_Investment Analysis & Strategy vs target for MSFT.US with original MLR line
# Plotting sentiment_finbert_Layoffs & Corporate Restructuring vs target for MSFT.US with original MLR line
# Plotting sentiment_finbert_Legal & Regulatory Changes vs target for MSFT.US with original MLR line
# Plotting sentiment_finbert_Market Movements & Trading News vs target for MSFT.US with original MLR line
# Plotting sentiment_finbert_Mergers, Acquisitions & Deals vs target for MSFT.US with original MLR line
# Plotting sentiment_finbert_Product News & Updates vs target for MSFT.US with original MLR line
# Plotting sentiment_finbert_Semiconductor & Chip Industry News vs target for MSFT.US with original MLR line
# Plotting total_count_CEO & Influencer News vs target for MSFT.US with original MLR line
# Plotting total_count_Corporate Earnings & Financials vs target for MSFT.US with original MLR line
# Plotting total_count_Corporate Strategy & Growth vs target for MSFT.US with original MLR line
# Plotting total_count_Economic Indicators & Fed Policy vs target for MSFT.US with original MLR line
# [MSFT.US | total_count_Economic Indicators & Fed Policy] Feature nearly constant; skipping.
# Plotting total_count_General Business & News Reporting vs target for MSFT.US with original MLR line
# Plotting total_count_Geopolitical & Trade News vs target for MSFT.US with original MLR line
# Plotting total_count_Innovation & Future Tech vs target for MSFT.US with original MLR line
# Plotting total_count_Investment & Hedge Fund Activity vs target for MSFT.US with original MLR line
# Plotting total_count_Investment Analysis & Strategy vs target for MSFT.US with original MLR line
# Plotting total_count_Layoffs & Corporate Restructuring vs target for MSFT.US with original MLR line
# Plotting total_count_Legal & Regulatory Changes vs target for MSFT.US with original MLR line
# Plotting total_count_Market Movements & Trading News vs target for MSFT.US with original MLR line
# Plotting total_count_Mergers, Acquisitions & Deals vs target for MSFT.US with original MLR line
# Plotting total_count_Product News & Updates vs target for MSFT.US with original MLR line
# Plotting total_count_Semiconductor & Chip Industry News vs target for MSFT.US with original MLR line
# Plotting total_news vs target for MSFT.US with original MLR line
# Plotting day_sentiment vs target for MSFT.US with original MLR line
# Plotting ret_1d vs target for MSFT.US with original MLR line
# Plotting market_ret_1d vs target for MSFT.US with original MLR line
# Plotting ret_5d vs target for MSFT.US with original MLR line
# Plotting market_ret_5d vs target for MSFT.US with original MLR line
# Plotting ret_10d vs target for MSFT.US with original MLR line
# Plotting market_ret_10d vs target for MSFT.US with original MLR line
# Plotting ret_21d vs target for MSFT.US with original MLR line
# Plotting market_ret_21d vs target for MSFT.US with original MLR line

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import statsmodels.api as sm

# def plot_feature_vs_target_with_mlr_line(X, y, results, feature_name, symbol):
#     """
#     Plot:
#       - scatter: feature vs TARGET (actual y)
#       - line: projection of the ORIGINAL multiple linear regression
#               onto (feature, y) using same coefficients (no refit).

#     X: DataFrame of features (no constant column)
#     y: Series of target values (same index as X)
#     results: statsmodels OLS results from your MULTI regression
#     feature_name: column to put on x-axis
#     symbol: ticker string (for titles)
#     """
#     if feature_name not in X.columns:
#         print(f"[{symbol}] Feature {feature_name} not in X.")
#         return

#     # Build subset and drop NaNs
#     sub = X[[feature_name]].copy()
#     sub["y_true"] = y
#     sub = sub.dropna()

#     if sub[feature_name].nunique() < 2:
#         print(f"[{symbol} | {feature_name}] Feature nearly constant; skipping line.")
#         return

#     x = sub[feature_name].values
#     y_true = sub["y_true"].values

#     # Use the SAME multi linear regression coefficients
#     params = results.params

#     if feature_name not in params.index:
#         print(f"[{symbol} | {feature_name}] No coefficient in model; skipping.")
#         return

#     beta_j = params[feature_name]
#     beta_0 = params["const"]

#     # For the intercept of the 2D line, hold other features at their mean
#     # in THIS plotting sample
#     other_feats = [col for col in X.columns if col != feature_name]

#     # Means for the same rows we're plotting
#     X_plot = X.loc[sub.index, other_feats].copy()
#     means_other = X_plot.mean()

#     # Sum_{k!=j} beta_k * mean(x_k)
#     offset_other = 0.0
#     for col in other_feats:
#         if col in params.index:
#             offset_other += params[col] * means_other[col]

#     intercept_line = beta_0 + offset_other  # consistent with original MLR

#     # Build line over range of x in this sample
#     x_line = np.linspace(x.min(), x.max(), 100)
#     y_line = intercept_line + beta_j * x_line

#     # ---- Plot ----
#     plt.figure(figsize=(8, 5))
#     plt.scatter(x, y_true, alpha=0.5, label="Actual target")
#     plt.plot(x_line, y_line, linestyle="--",
#              label=f"MLR line: y = {intercept_line:.4f} + {beta_j:.4f}·{feature_name}")

#     plt.xlabel(feature_name)
#     plt.ylabel(y.name or "target")
#     plt.title(f"{symbol}: {y.name or 'target'} vs {feature_name} (original MLR)")
#     plt.grid(True)
#     plt.legend()
#     plt.show()

# %%
# X_test_no_const = apple_df_x_test.copy()  # features only
# y_test = apple_df_y_test

# for feature in features:
#     if feature not in X_test_no_const.columns:
#         continue

#     print(f"Plotting {feature} vs target for MSFT.US with original MLR line")
#     plot_feature_vs_target_with_mlr_line(
#         X=X_test_no_const,
#         y=y_test,
#         results=results,
#         feature_name=feature,
#         symbol="MSFT.US"
#     )

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import statsmodels.api as sm

# def plot_feature_vs_multireg_prediction(X_test, y_pred, feature_name, symbol):
#     """
#     Plot scatter of a single feature vs the predictions from your
#     MULTIPLE regression model, with a regression line based on OLS.

#     X_test: DataFrame of test features (NO constant column)
#     y_pred: 1D array/Series of predictions from your multiple OLS model
#     feature_name: column name in X_test
#     symbol: ticker string for labeling
#     """
#     # Build small DataFrame for cleaning
#     sub = X_test[[feature_name]].copy()
#     sub["y_pred"] = np.asarray(y_pred)

#     # Keep only finite values
#     mask = np.isfinite(sub[feature_name]) & np.isfinite(sub["y_pred"])
#     sub = sub[mask]

#     if len(sub) < 3:
#         print(f"[{symbol} | {feature_name}] Not enough clean points to fit a line. Showing scatter only.")
#         plt.figure(figsize=(8, 5))
#         plt.scatter(sub[feature_name], sub["y_pred"], alpha=0.5, label="Predicted values")
#         plt.xlabel(feature_name)
#         plt.ylabel("Predicted target (ŷ)")
#         plt.title(f"{symbol}: multivariate prediction vs {feature_name}")
#         plt.grid(True)
#         plt.legend()
#         plt.show()
#         return

#     # Check that x actually varies
#     if sub[feature_name].nunique() < 2:
#         print(f"[{symbol} | {feature_name}] Feature is (almost) constant. Showing scatter only.")
#         plt.figure(figsize=(8, 5))
#         plt.scatter(sub[feature_name], sub["y_pred"], alpha=0.5, label="Predicted values")
#         plt.xlabel(feature_name)
#         plt.ylabel("Predicted target (ŷ)")
#         plt.title(f"{symbol}: multivariate prediction vs {feature_name}")
#         plt.grid(True)
#         plt.legend()
#         plt.show()
#         return

#     # Fit line: y_pred = a + b * feature using statsmodels OLS
#     try:
#         X_ols = sm.add_constant(sub[feature_name])
#         ols_model = sm.OLS(sub["y_pred"], X_ols).fit()
#         a = ols_model.params["const"]
#         b = ols_model.params[feature_name]
#     except Exception as e:
#         print(f"[{symbol} | {feature_name}] Could not fit line ({e}). Showing scatter only.")
#         plt.figure(figsize=(8, 5))
#         plt.scatter(sub[feature_name], sub["y_pred"], alpha=0.5, label="Predicted values")
#         plt.xlabel(feature_name)
#         plt.ylabel("Predicted target (ŷ)")
#         plt.title(f"{symbol}: multivariate prediction vs {feature_name}")
#         plt.grid(True)
#         plt.legend()
#         plt.show()
#         return

#     # Scatter + regression line
#     x = sub[feature_name].values
#     y = sub["y_pred"].values

#     plt.figure(figsize=(8, 5))
#     plt.scatter(x, y, alpha=0.5, label="Predicted values (from multiple OLS)")

#     x_line = np.linspace(x.min(), x.max(), 100)
#     y_line = a + b * x_line
#     plt.plot(x_line, y_line, linestyle="--",
#              label=f"Line: ŷ = {a:.4f} + {b:.4f}·{feature_name}")

#     plt.xlabel(feature_name)
#     plt.ylabel("Predicted target (ŷ)")
#     plt.title(f"{symbol}: multivariate prediction vs {feature_name}")
#     plt.legend()
#     plt.grid(True)
#     plt.show()

# %%
# # Remove the constant column when plotting vs features
# X_test_no_const = apple_df_x_test.copy()   # this already has only the feature columns

# for feature in features:
#     if feature not in X_test_no_const.columns:
#         continue  # skip if that feature isn't in this symbol's test data

#     print(f"Plotting {feature} vs multivariate prediction for MSFT.US")
#     plot_feature_vs_multireg_prediction(
#         X_test=X_test_no_const,
#         y_pred=predictions,
#         feature_name=feature,
#         symbol='MSFT.US'
#     )

# %% [markdown]
# # Unified Code

# %%
MAG7 = [
    'AAPL.US',
    'MSFT.US',
    'GOOGL.US',
    'AMZN.US',
    'META.US',
    'NVDA.US',
    'TSLA.US'
]

# %%
def prepare_symbol_data(symbol, cutoff_date='2025-06-01'):
    """
    Mirror your apple_df / train-test logic for any symbol.
    Uses global avg_sentiment_df, features, and target.
    """
    df_sym = avg_sentiment_df.loc[avg_sentiment_df['symbol_query'] == symbol, :].copy()
    df_sym = df_sym.sort_values('date')

    # Drop rows where target or any feature is NaN
    df_sym = df_sym.dropna(subset=features + [target])

    df_train = df_sym.loc[df_sym['date'] < cutoff_date, :].copy()
    df_test  = df_sym.loc[df_sym['date'] >= cutoff_date, :].copy()

    X_train = df_train[features]
    y_train = df_train[target]

    X_test  = df_test[features]
    y_test  = df_test[target]

    return X_train, y_train, X_test, y_test, df_sym

# %%
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

def run_ols_for_symbol(symbol, cutoff_date='2025-06-01', make_plots=True):
    X_train, y_train, X_test, y_test, df_sym = prepare_symbol_data(symbol, cutoff_date)

    # Add constant and fit model (same as before)
    X_train_const = sm.add_constant(X_train)
    model = sm.OLS(y_train, X_train_const)
    results = model.fit()

    # Predictions on test set
    X_test_const = sm.add_constant(X_test)
    y_pred = results.predict(X_test_const)

    # Residuals
    residuals = y_test - y_pred

    if make_plots:
        # (1) Residuals vs predicted (unchanged)
        plt.figure(figsize=(10, 6))
        plt.scatter(y_pred, residuals, alpha=0.5)
        plt.axhline(y=0, color='r', linestyle='--')
        plt.xlabel('Predicted Values')
        plt.ylabel('Residuals')
        plt.title(f'{symbol} – Residuals vs. Predicted Values (OLS)')
        plt.grid(True)
        plt.show()

        # (2) Actual vs predicted with *regression line through the points*
        plt.figure(figsize=(10, 6))
        plt.scatter(y_test, y_pred, alpha=0.5, label='Observed points')

        # Fit simple regression: y_pred = a + b * y_test
        coeffs = np.polyfit(y_test, y_pred, 1)  # [slope, intercept]
        slope, intercept = coeffs[0], coeffs[1]

        x_line = np.linspace(y_test.min(), y_test.max(), 100)
        y_line = intercept + slope * x_line

        plt.plot(x_line, y_line, linestyle='--', label=f'Regression line: y = {intercept:.2f} + {slope:.2f}x')

        plt.xlabel('Actual Next-Day Close')
        plt.ylabel('Predicted Next-Day Close')
        plt.title(f'{symbol} – Actual vs Predicted (with regression line)')
        plt.legend()
        plt.grid(True)
        plt.show()

    return results, y_test, y_pred, residuals

# %%
all_results = {}
all_predictions = []

for symbol in MAG7:
    print("=" * 80)
    print(f"Running OLS for {symbol}")
    print("=" * 80)

    results, y_test, y_pred, residuals = run_ols_for_symbol(symbol)

    # Store the statsmodels results object
    all_results[symbol] = results

    # Build a small DataFrame with predictions for that symbol
    df_sym = avg_sentiment_df.loc[avg_sentiment_df['symbol_query'] == symbol, :].copy()
    df_sym = df_sym.sort_values('date')
    df_sym = df_sym[df_sym['date'] >= '2025-06-01'].copy()
    df_sym = df_sym.loc[df_sym[target].notna(), :]

    df_out = pd.DataFrame({
        'symbol_query': symbol,
        'date': df_sym['date'].values[:len(y_test)],
        'actual_next_day_close': y_test.values,
        'predicted_next_day_close': y_pred.values,
        'residual': residuals.values
    })

    all_predictions.append(df_out)

# Combine predictions across all MAG7
predictions_mag7 = pd.concat(all_predictions, ignore_index=True)
# Out:
# ================================================================================
# Running OLS for AAPL.US
# ================================================================================
# ================================================================================
# Running OLS for MSFT.US
# ================================================================================
# ================================================================================
# Running OLS for GOOGL.US
# ================================================================================
# ================================================================================
# Running OLS for AMZN.US
# ================================================================================
# ================================================================================
# Running OLS for META.US
# ================================================================================
# ================================================================================
# Running OLS for NVDA.US
# ================================================================================
# ================================================================================
# Running OLS for TSLA.US
# ================================================================================

# %%
summary_rows = []

for symbol, res in all_results.items():
    row = {
        'symbol': symbol,
        'n_obs': int(res.nobs),
        'r2': res.rsquared,
        'adj_r2': res.rsquared_adj,
        'sigma_resid': res.mse_resid ** 0.5
    }
    summary_rows.append(row)

slr_summary = pd.DataFrame(summary_rows)
slr_summary
# Out:
#      symbol  n_obs        r2    adj_r2  sigma_resid
# 0   AAPL.US    596  0.528805  0.495753    19.792848
# 1   MSFT.US    595  0.736232  0.717697    31.524837
# 2  GOOGL.US    594  0.599036  0.570810    18.319085
# 3   AMZN.US    599  0.669420  0.646357    23.273109
# 4   META.US    564  0.578753  0.547401   103.664074
# 5   NVDA.US    571  0.665319  0.640737    24.930902
# 6   TSLA.US    593  0.521693  0.487961    46.644546

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

def plot_scatter_with_regression(df, x_col, y_col, title=None):
    # Keep only the two columns and drop rows with NaN
    sub = df[[x_col, y_col]].dropna().copy()
    x = sub[x_col].values
    y = sub[y_col].values

    # Fit line: y = a + b x using statsmodels (consistent with your OLS)
    X = sm.add_constant(x)          # adds intercept term
    model = sm.OLS(y, X).fit()
    a, b = model.params             # intercept, slope

    # Scatter
    plt.figure(figsize=(8, 5))
    plt.scatter(x, y, alpha=0.5, label="Data points")

    # Regression line
    x_line = np.linspace(x.min(), x.max(), 100)
    y_line = a + b * x_line
    plt.plot(x_line, y_line, linestyle="--",
             label=f"Regression line: y = {a:.2f} + {b:.2f}x")

    plt.xlabel(x_col)
    plt.ylabel(y_col)
    if title is None:
        title = f"{y_col} vs {x_col}"
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

    return model

# %%
symbol = "MSFT.US"
# feature_target = "day_sentiment"
target = "target_day_end_raw_close_next_day"

for f in features:
  feature_target = f
  aapl_df = avg_sentiment_df[avg_sentiment_df["symbol_query"] == symbol].copy()
  model = plot_scatter_with_regression(
    aapl_df,
    x_col=feature_target,
    y_col=target,
    title=f"{symbol}: {target} vs {feature_target}"
    )
  print(model.summary())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Microsoft Regression
